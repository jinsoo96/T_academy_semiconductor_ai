# %% [markdown]
# ## Code 목차
#
#
# - [1. 분석환경 구축](#01)
#     - [1.1  Colab 구글드라이브 연동](#01-01)
#     - [1.2  라이브러리 임포트](#01-02)
# - [2. 데이터 읽기](#02)
#     - [2.1 데이터 통합](#02-01)
#     - [2.2 데이터 설명](#02-02)
# - [3. 탐색적 데이터 분석](#03)
#
#     - [3.1 타깃 변수 분포 확인하기](#03-01)
#     - [3.2 센서 변수와 타깃 변수의 상관관계 파악](#03-02)
#     - [3.3 범주형 변수에 따른 타깃 변수의 변화](#03-03)
#     - [3.4 전체 공정 소요시간에 따른 타깃 변수의 변화](#03-04)
#     - [3.5 센서의 집약된 통계량에 따른 타깃 변수의 변화](#03-05)
#
# - [4. 데이터 전처리](#04)
#     - [4.1 내부 데이터를 통한 변수 생성](#04-01)
#     - [4.2 이상치 치환하기](#04-02)
#     - [4.3 분산이 적은 변수 제거](#04-03)
#     - [4.4 표준화](#04-04)
#     - [4.5 원-핫 인코딩](#04-05)
#     - [4.6 변수 선택](#04-06)
#
# - [5. 모델링](#05)
#     - [5.1 데이터 분할](#05-01)
#     - [5.2 릿지 회귀 모델](#05-02)
#     - [5.3 랜덤 포레스트 모델](#05-03)
#     - [5.4 최종 모델 구축](#05-04)
#     - [5.5 결과 해석](#05-05)
#     - [5.6 예측 결과 파일 제출](#05-06)

# %% [markdown]
# <a name='01'></a>
# ## 1. 분석환경 구축

# %% [markdown]
# <a name='01-01'></a>
# ### 1.1 Colab 구글 드라이브 연동

# %% [markdown]
# <a name='01-02'></a>
# ### 1.2 라이브러리 임포트

# %%
import warnings
warnings.filterwarnings('ignore')

# 데이터 읽기를 위한 라이브러리
import numpy as np

import pandas as pd
import scipy as sp
import statsmodels.api as sm
from datetime import datetime, date, timedelta
from sklearn.preprocessing import StandardScaler, LabelEncoder

# 탐색적 데이터 분석을 위한 라이브러리
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew, norm, probplot, boxcox
from itertools import product

# 모델링을 위한 라이브러리
from sklearn.decomposition import PCA
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_selection import SelectKBest, mutual_info_regression, VarianceThreshold, RFECV
from catboost import CatBoostRegressor
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.outliers_influence import variance_inflation_factor


from bayes_opt import BayesianOptimization  # 자꾸 오류뜸ㄴ
import lightgbm as lgb
import xgboost

#from pycaret.regression import * #까는거 오지게 빡셈

# %% [markdown]
# <a name='02'></a>
# ## 2. 데이터 읽기
#
# 데이터 파일을 불러옵니다.

# %%
# 구글 드라이브 내 데이터가 위치한 경로를 설정합니다.
# path = "/content/drive/MyDrive/scv/"
path = "./data/"
# 학습용 데이터 
train_sensor = pd.read_csv(f'{path}train_sensor.csv')
train_quality = pd.read_csv(f'{path}train_quality.csv')

# 평가용 데이터 
predict_sensor = pd.read_csv(f'{path}predict_sensor.csv')

# %% [markdown]
# <a name='02-01'></a>
# ### 2.1 데이터 통합
#
# 학습 데이터의 특징과 타깃 변수가 다른 파일에 존재하므로, 이를 통합하기 위한 작업을 수행합니다.
#
# key_val 을 기준으로 train_sensor (X인자)와 train_quality (y인자)의 데이터프레임을 통합합니다.
#
# key_val 별 665개의 센서값 컬럼을 생성하기 위해 pandas의 pivot_table 함수를 사용합니다.
#
# pivot_table 의 주요 인자는 **index, agg_func, columns** 입니다.
#
# 1. **index** : key_val 을 기준으로 그룹핑을 하고자 하므로, index 에 key_val 과 그의 상위 그룹인 module_name 을 입력합니다.
# 2. **agg_func** : values 에 mean_val 을 입력하고, 해당 값에 대한 산식을 sum으로 설정합니다.
# 3. **columns** : step_param 을 columns 인자로 주어, key_val 별 665개의 스텝 단위의 센서 특징을 생성합니다.

# %%
def make_dataset(X, y=None):
    
    # -----------------------------------
    # train_sensor (X 인자)
    # -----------------------------------
    df_X = X.copy()
    # step_id가 한자리일 경우 앞에 0으로 채움
    df_X['step_id'] = df_X['step_id'].apply(lambda x: str(x).zfill(2))
    # step_id 와 param_alias 를 결합한 임시 컬럼 step_param 을 생성합니다. ex. 17_EPD_para4
    df_X['step_param'] = df_X[['step_id', 'param_alias']].apply(lambda x: '_'.join(x), axis=1)
    print('feature 개수 : {}'.format(len(set(df_X['step_param']))))
    df_X_tmp = df_X.pivot_table(index = ['module_name','key_val'], columns = 'step_param', values='mean_val', aggfunc='sum')
    # 데이터 통합을 위해 인덱스를 key_val 로 재설정합니다. 
    df_X_tmp = df_X_tmp.reset_index(level=[0, 1])
    df_X_tmp.set_index('key_val', inplace=True)

    # -----------------------------------
    # 시간 데이터 
    # -----------------------------------
    df_X['end_time_tmp'] = df_X.apply(lambda x: x['step_id'] + '_end_time', axis=1)
    df_X['end_time'] = pd.to_datetime(df_X['end_time'])

    # end_time 은 센서 데이터가 서버에 도달한 시간으로 스텝 내 오차가 발생할 수 있습니다. 동일 스텝 구간내 공정 완료 시간이 다른 경우, max 함수를 사용하여 가장 최근에 
    # 수집된 시간을 가져옵니다. 
    df_time_tmp = df_X.pivot_table(index = ['key_val'], columns = 'end_time_tmp', values='end_time', aggfunc=lambda x : max(x.unique()))
    df_time_tmp = df_time_tmp.reset_index()
    df_time_tmp.set_index('key_val', inplace=True)

    # -----------------------------------
    # train_quality (y 인자)
    # -----------------------------------

    if y is None : # 평가용 데이터 
      
        col_target = []
        col_idx = ['module_name', 'key_val']
        df_complete = pd.concat([df_X_tmp, df_time_tmp], axis=1).reset_index()
        df_complete = df_complete.rename(columns={'index': 'key_val'})  
    
    else : # 학습용 데이터 
        df_y = y.copy()
        df_y.set_index('key_val', inplace=True)
      
        col_target = ['y']
        col_idx = ['module_name', 'key_val', 'end_dt_tm']
      
        # 센서 데이터, 시간데이터, 품질지표에 대하여 인덱스(key_val)기준으로 데이터프레임을 통합합니다.
        df_complete = pd.concat([df_X_tmp, df_time_tmp, df_y], axis=1).reset_index()
        df_complete = df_complete.rename(columns={'index': 'key_val'})
        # 컬럼 이름을 변경합니다.  
        df_complete.rename(columns={'msure_val':'y'}, inplace=True)

    # 컬럼 순서를 정렬합니다. 
    col_feats = df_X['step_param'].unique().tolist()
    col_feats.sort()
    col_time = [s for s in df_complete.columns.tolist() if "_end_time" in s]
    col_all = col_idx + col_target + col_feats + col_time
    df_complete = df_complete[col_all]
    
    # 컬럼을 소문자로 변경합니다. 
    df_complete.columns = df_complete.columns.str.lower()

    return df_complete

# %%
# 학습용 데이터 
train = make_dataset(train_sensor, train_quality)
# 평가용 데이터 
predict = make_dataset(predict_sensor)
# Out:
# feature 개수 : 665
# feature 개수 : 665

# %% [markdown]
# <a name='02-02'></a>
# ### 2.2 데이터 설명

# %%
def describe_(df, pred=None): 
    
    obs = df.shape[0]
    types = df.dtypes # 자료형 
    counts = df.apply(lambda x: x.count()) # 값의 갯수 
    uniques = df.apply(lambda x: x.unique()) # 고유값 
    distincts = df.apply(lambda x: x.unique().shape[0]) # 고유값의 갯수 
    nulls = df.apply(lambda x: x.isnull().sum()) # 결측치의 갯수  
    nulls_ratio = (df.isnull().sum()/ obs) * 100 # 결측 비율 
    skewness = df.skew() # 왜도  
    kurtosis = df.kurt() # 첨도  
    
    print('Data shape:', df.shape)
    
    if pred is None:
        cols = ['types', 'counts', 'distincts', 'nulls', 'nulls_ratio', 'uniques', 'skewness', 'kurtosis']
        values_ = pd.concat([types, counts, distincts, nulls, nulls_ratio, uniques, skewness, kurtosis], axis = 1)

    else:
        corr = df.corr()[pred]
        values_ = pd.concat([types, counts, distincts, nulls, nulls_ratio, uniques, skewness, kurtosis, corr], axis = 1, sort=False)
        corr_col = 'corr '  + pred
        cols = ['types', 'counts', 'distincts', 'nulls', 'nulls_ratio', 'uniques', 'skewness', 'kurtosis', corr_col ]

    values_.columns = cols
    dtypes = values_.types.value_counts()
    print('___________________________\nData types:\n',values_.types.value_counts())
    print('___________________________')
    
    return values_

# %% [markdown]
# 학습 데이터의 수는 611건이며, 665개의 센서 데이터와 7개의 시간 데이터의 특성을 가지고 있습니다.

# %%
details = describe_(train, 'y')
display(details.sort_values(by='corr y', ascending=False))
# Out:
# Data shape: (611, 676)
# ___________________________
# Data types:
#  float64           666
# datetime64[ns]      7
# object              3
# Name: types, dtype: int64
# ___________________________
#                          types  counts  distincts  nulls  nulls_ratio  \
# y                      float64     611        591      0          0.0
# 20_temp_para24         float64     611        575      0          0.0
# 13_temp_para24         float64     611        189      0          0.0
# 12_temp_para24         float64     611        425      0          0.0
# 17_temp_para24         float64     611        419      0          0.0
# ...                        ...     ...        ...    ...          ...
# 12_end_time     datetime64[ns]     611        611      0          0.0
# 13_end_time     datetime64[ns]     611        611      0          0.0
# 17_end_time     datetime64[ns]     611        611      0          0.0
# 18_end_time     datetime64[ns]     611        611      0          0.0
# 20_end_time     datetime64[ns]     611        611      0          0.0
#
#                                                           uniques  skewness  \
# y               [1257.8492, 1253.30152, 1265.93544, 1248.5508,... -0.059197
# 20_temp_para24  [50.28713, 51.87376, 49.72592, 51.89357, 49.61... -0.438729
# 13_temp_para24  [69.5625, 72.6875, 68.3125, 71.125, 66.125, 72... -0.309862
# 12_temp_para24  [68.45, 70.56667, 67.43333, 70.66666, 66.55932... -0.340203
# 17_temp_para24  [69.63333, 72.21667, 69.96667, 71.73333, 69.35... -0.439029
# ...                                                           ...       ...
# 12_end_time     [2021-10-18T11:16:38.000000000, 2021-10-04T11:...       NaN
# 13_end_time     [2021-10-18T11:16:54.000000000, 2021-10-04T11:...       NaN
# 17_end_time     [2021-10-18T11:24:51.000000000, 2021-10-04T11:...       NaN
# 18_end_time     [2021-10-18T11:25:07.000000000, 2021-10-04T11:...       NaN
# 20_end_time     [2021-10-18T11:31:58.000000000, 2021-10-04T11:...       NaN
#
#                 kurtosis    corr y
# y               0.342927  1.000000
# 20_temp_para24  0.090808  0.196888
# 13_temp_para24 -0.110704  0.194742
# 12_temp_para24 -0.064225  0.189035
# 17_temp_para24  0.009083  0.183320
# ...                  ...       ...
# 12_end_time          NaN       NaN
# 13_end_time          NaN       NaN
# 17_end_time          NaN       NaN
# 18_end_time          NaN       NaN
# 20_end_time          NaN       NaN
#
# [676 rows x 9 columns]

# %% [markdown]
# <a name='03'></a>
# ## 3. 탐색적 데이터 분석
#
# 탐색적 데이터 분석을 통해 **데이터를 이해**하고, 모델에 유용한 **특징을 생성**할 수 있습니다.
#
# - 데이터에 대한 이해를 높이기 위해 타깃 변수의 분포 (3.1절) , 각 센서 변수와 타깃 변수와의 상관 관계 (3.2절)를 파악합니다.
#
# - 새로운 특징을 도출하기 위해 범주형 변수에 따른 타깃 변수의 변화 (3.3절) , 전체 공정 소요시간에 따른 타깃 변수의 변화 (3.4절) , 센서 변수의 집약된 통계량 (3.5절) 을 확인해봅니다.

# %%
# EDA를 위한 학습 데이터를 복사합니다.
df_eda = train.copy()

# 센서 컬럼과 날짜 컬럼을 정의합니다. 
col_sensor = df_eda.iloc[:, 4:-7].columns.tolist() 
col_time = df_eda.filter(regex='end').columns.tolist() 

assert len(col_sensor) == 665
assert len(col_time) == 8 

# 3.4절 공정 소요시간 분석에 필요한 변수를 정의합니다. 
lst_steps = ['04','06','12','13','17','18', '20']
lst_stepsgap = ['0406','0412','0413','0417','0418','0612','0613','0617','0618','0620',
                '1213','1217','1218','1220','1317','1318','1320','1718','1720','1820']

lst_sensors = []
for step in lst_steps:
    _ = [col for col in col_sensor if col[:2] == step]
    lst_sensors.append(_)

sensors_nm = list(map(lambda x: x[3:], lst_sensors[0]))

# 시간과 관련한 분석을 진행하기 위하여 날짜형으로 변환합니다. 
df_eda[col_time] = df_eda[col_time].apply(pd.to_datetime)

# %% [markdown]
# <a name='03-01'></a>
# ### 3.1 타깃 변수 분포 확인하기
#
# 학습 데이터를 이용해 타깃 변수의 분포를 살펴보겠습니다.
#
# Seaborn 의 **distplot** 과 **probplot** 을 사용하여 타깃 변수의 분포 범위와 해당 값이 특정 구간에 치우쳐 있는지를 확인합니다.

# %%
def QQ_plot(data, measure):
    
    # 그래프의 크기를 지정합니다.
    fig = plt.figure(figsize=(10,4))
    
    # 1행 2열의 첫번째 히스토그램 그래프입니다.
    fig1 = fig.add_subplot(121)
    (mu, sigma) = norm.fit(data)
    # distplot 으로 타깃 변수의 분포를 확인합니다. kde = True를 입력하면 커널밀도추정 결과를 함께 표기할 수 있습니다.
    sns.distplot(data, kde=True, fit=norm)
    fig1.legend(['KDE', f'N({round(mu, 2)},{round(sigma**2, 2)})'], loc='upper right')
    fig1.set_title(f'{measure} Distribution', loc='center')
    fig1.set_xlabel(f'{measure}')

    # 1행 2열의 두번째 QQ Plot 그래프입니다.
    fig2 = fig.add_subplot(122)
    # 정규분포와 타깃변수의 분포를 비교합니다.
    res = probplot(data, plot=fig2)
    fig2.set_title(f'{measure} Probability Plot', loc='center')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# 타깃은 평균 1263.41, 분산 67.16 인 정규분포를 거의 따른다고 볼 수 있습니다.

# %%
QQ_plot(df_eda['y'], 'y')

# %%
len(df_eda[df_eda['y'] < 1240])
# Out:
# 3

# %% [markdown]
# <a name='03-02'></a>
# ### 3.2 센서 변수와 타깃 변수의 상관관계 파악
# 총 665개의 센서 변수와 타깃 변수 y 간의 관련성이 있는지 확인해보겠습니다.
#
# 95개의 센서 변수는 총 7개의 공정 스텝 (4, 6, 12, 13, 17, 18, 20) 단위로 수집됩니다.

# %%
def regplots(cols, data):
    
    # 각 센서별 7개의 스텝을 가지므로 행이 2개이고, 열이 4개인 서브 플롯을 생성합니다.
    fig, axes = plt.subplots(nrows=2, ncols=4, sharey=True, figsize=(15,8))
    
    # 서브 플롯 간의 세로 간격(hspace) 가로 간격(wspace)을 설정합니다. 
    fig.subplots_adjust(hspace=.4, wspace=.1)
    
    for i, ax in zip(range(len(cols)), axes.flat):

        sns.regplot(x=cols[i], y='y', data=data, ax=ax)
        ax.set_title(f'{cols[i].upper()}')
        ax.set_xlabel('')
        ax.set_ylabel('')
    
    # 8번째 서브 플롯은 필요 없으므로 표기하지 않습니다. 
    axes.flat[-1].set_visible(False)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# 수치형 변수 X 수치형 변수 조합 시각화에 유용한 산점도 그래프 scatter plot 를 작성합니다.
#
# **regplot** 을 사용하여 산점도와 함께 데이터의 경향성을 나타내는 추세선까지 함께 표시합니다.

# %%
for ix, sensor_nm in enumerate(sensors_nm):
    print(f'*****{[sensor_nm]}')

    # tmp_lst 는 {스텝}_{센서명} 형식으로 센서의 총 7개의 스텝 컬럼 리스트를 생성합니다.
    # ex. 04_efem_para2, 06_efem_para2, ..., 20_efem_para2
    tmp_lst = list(map(lambda x: f'{x}_{sensor_nm}', lst_steps))
    regplots(tmp_lst, df_eda)
    
    # 총 95개의 센서를 시각화를 할 경우 아래 코드를 주석 처리 합니다.
    if ix == 0:
        break
# Out:
# *****['efem_para2']

# %% [markdown]
# <a name='03-03'></a>
# ### 3.3 범주형 변수에 따른 타깃 변수의 변화
#
# 총 모듈(module_name)의 고유값의 갯수는 47개입니다. 모듈 이름은 _ 를 기준으로 EQ와 PM 식별자로 조합되어 있습니다.

# %%
idx = 'module_name'
# 모듈의 고유값과 고유값의 갯수를 구합니다.
module_unq = df_eda[idx].unique()
module_nunq = df_eda[idx].nunique()

print(f'***')
print(f'No. of Module : {module_nunq}')
print(f'{module_unq}')
# Out:
# ***
# No. of Module : 47
# ['EQ10_PM1' 'EQ10_PM2' 'EQ10_PM5' 'EQ10_PM6' 'EQ11_PM1' 'EQ11_PM2'
#  'EQ11_PM5' 'EQ11_PM6' 'EQ12_PM1' 'EQ12_PM2' 'EQ12_PM5' 'EQ12_PM6'
#  'EQ1_PM1' 'EQ1_PM2' 'EQ1_PM5' 'EQ1_PM6' 'EQ2_PM1' 'EQ2_PM2' 'EQ2_PM5'
#  'EQ2_PM6' 'EQ3_PM1' 'EQ3_PM2' 'EQ3_PM5' 'EQ3_PM6' 'EQ4_PM1' 'EQ4_PM2'
#  'EQ4_PM5' 'EQ4_PM6' 'EQ5_PM1' 'EQ5_PM2' 'EQ5_PM5' 'EQ5_PM6' 'EQ6_PM1'
#  'EQ6_PM2' 'EQ6_PM5' 'EQ6_PM6' 'EQ7_PM1' 'EQ7_PM2' 'EQ7_PM5' 'EQ7_PM6'
#  'EQ8_PM1' 'EQ8_PM2' 'EQ8_PM5' 'EQ8_PM6' 'EQ9_PM1' 'EQ9_PM2' 'EQ9_PM5']

# %% [markdown]
# 범주의 정도를 상위 레벨에서 보기 위하여 EQ를 기준으로 재범주화 해보겠습니다.
#
# apply 를 사용하여 모듈 이름의 EQ 식별자 부분만 추출하여 module_name_eq 컬럼에 값을 저장합니다.

# %%
# 모듈 이름의 상위 집계단위를 나타내는 module_name_eq 범주형 변수를 생성하는 함수입니다.
def gen_cate_feats(df):
    df['module_name_eq'] = df['module_name'].apply(lambda x : x.split('_')[0])
    return df 
   
df_eda = gen_cate_feats(df_eda)
sns.boxplot(x='module_name_eq', y='y', data=df_eda)
# Out:
# <AxesSubplot:xlabel='module_name_eq', ylabel='y'>

# %% [markdown]
# <a name='03-04'></a>
# ### 3.4 전체 공정 소요시간에 따른 타깃 변수의 변화
#
# 전체 및 개별 공정 소요시간 변수를 생성하는 함수를 작성합니다.
#
# 전체 공정 소요시간은 마지막 공정 완료시간 ***20_end_time*** 과 첫번째 공정 완료시간 **04_end_time** 의 차이(초)를 계산한 값입니다.

# %%
# 전체 및 개별 공정 소요시간 변수를 생성하는 함수입니다.
def gen_duration_feats(df, lst_stepsgap):
    
    # 전체 공정 소요시간(초) 변수를 생성합니다. 
    df['gen_tmdiff'] = (df['20_end_time'] - df['04_end_time']).dt.total_seconds()
    
    # 개별 스텝간 공정 소요시간(초) 변수를 생성합니다. 
    # ex. gen_tmdiff_0406 : 04 스텝 공정 완료 시간과 06 스텝 공정 완료 시간의 차이 
    for stepgap in lst_stepsgap:
        df[f'gen_tmdiff_{stepgap}'] = (df[f'{stepgap[2:]}_end_time'] - df[f'{stepgap[:2]}_end_time']).dt.total_seconds()

    return df

df_eda = gen_duration_feats(df_eda, lst_stepsgap)

# %% [markdown]
# 전체 공정 소요시간은 최소 30.6분에서 최대 31.9분입니다.
#
# 개별 스텝간 공정 소요시간도 확인하였을 시, 6번째 스텝에서 12번째 스텝 간 소요시간이 가장 길었습니다.

# %%
# 전체 공정 소요시간 및 개별 공정 소요시간 컬럼을 리스트 형태로 추출합니다. 
col_tmdiff = df_eda.filter(regex='gen_tmdiff($|_\d)').columns.tolist()

# 공정 소요시간의 통계값(최소, 최대, 평균)을 추출하는 함수입니다.
def tmdiff_stats(x):
    return [round(x.min()/60,1), round(x.max()/60,1), round(x.mean()/60,1)]

df_tmp = df_eda[col_tmdiff].apply(tmdiff_stats).T
df_tmp.columns = ['MIN', 'MAX', 'MEAN']
df_tmp
# Out:
#                   MIN   MAX  MEAN
# gen_tmdiff       30.6  31.9  31.5
# gen_tmdiff_0406   2.0   2.5   2.3
# gen_tmdiff_0412  15.3  16.6  16.2
# gen_tmdiff_0413  15.5  16.9  16.5
# gen_tmdiff_0417  23.4  24.8  24.4
# gen_tmdiff_0418  23.7  25.1  24.7
# gen_tmdiff_0612  13.3  14.2  13.9
# gen_tmdiff_0613  13.5  14.4  14.2
# gen_tmdiff_0617  21.5  22.4  22.1
# gen_tmdiff_0618  21.7  22.7  22.4
# gen_tmdiff_0620  28.6  29.5  29.2
# gen_tmdiff_1213   0.3   0.3   0.3
# gen_tmdiff_1217   8.2   8.2   8.2
# gen_tmdiff_1218   8.5   8.5   8.5
# gen_tmdiff_1220  15.3  15.4  15.3
# gen_tmdiff_1317   7.9   8.0   7.9
# gen_tmdiff_1318   8.2   8.2   8.2
# gen_tmdiff_1320  15.0  15.1  15.1
# gen_tmdiff_1718   0.3   0.3   0.3
# gen_tmdiff_1720   7.1   7.2   7.1
# gen_tmdiff_1820   6.8   6.9   6.8

# %% [markdown]
# 전체 공정 소요시간은 30분대 공정이 완료된 장비와 31분대에 공정이 완료된 장비로 뚜렷이 구분됩니다.
#
# 대부분의 장비는 31분대에 완료되었으며, 일찍 공정을 마친 장비는 주로 EQ7, EQ8 모듈입니다.

# %%
# 시각화를 위하여 1870초를 기준으로 일찍 마친 장비와 늦께 마친 장비를 구분합니다.
df_eda.loc[df_eda['gen_tmdiff'] < 1870, 'tmdiff_speed'] = 'E' # Early 
df_eda.loc[df_eda['gen_tmdiff'] > 1870, 'tmdiff_speed'] = 'L' # Late

fig, axes = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(10,5))
sns.scatterplot(x='gen_tmdiff', y='y', hue='tmdiff_speed', data = df_eda, ax=axes[0])
sns.scatterplot(x='gen_tmdiff', y='y', hue='module_name_eq', data = df_eda, ax=axes[1])
axes[0].legend(loc='lower left', ncol=2, title='tmdiff_speed')
axes[1].legend(loc='lower left', ncol=1, title='module_name_eq', bbox_to_anchor=(1.04, 0))

# %% [markdown]
# <a name='03-05'></a>
# ### 3.5 센서의 집약된 통계량에 따른 타깃 변수의 변화
#
# 센서 측정치에 대해 총 7개의 스텝을 집약한 표준편차를 확인해보겠습니다. 전 구간에서 센서 측정치의 흩어진 정도를 알 수 있습니다.

# %%
# 센서의 집약된 표준편차 변수를 생성하는 함수입니다.
def gen_stats_feats(df, sensors_nm, lst_steps):
    
    for sensor_nm in sensors_nm:

        # 센서별 총 7개의 스텝 컬럼 리스트를 생성합니다.
        # ex. 04_efem_para2, 06_efem_para2, ..., 20_efem_para2
        tmp_lst = list(map(lambda x: f'{x}_{sensor_nm}', lst_steps))

        # 전 스텝을 집약하여 센서의 표준편차 변수를 생성합니다. 
        df[f'gen_{sensor_nm}_std'] = df[tmp_lst].std(axis=1)
        
    return df

df_eda = gen_stats_feats(df_eda, sensors_nm, lst_steps)

# %%
# 센서의 집약된 평균 변수를 생성하는 함수입니다.
def gen_avg_feats(df, sensors_nm, lst_steps):
    
    for sensor_nm in sensors_nm:

        # 센서별 총 7개의 스텝 컬럼 리스트를 생성합니다.
        # ex. 04_efem_para2, 06_efem_para2, ..., 20_efem_para2
        tmp_lst = list(map(lambda x: f'{x}_{sensor_nm}', lst_steps))

        # 전 스텝을 집약하여 센서의 표준편차 변수를 생성합니다. 
        df[f'gen_{sensor_nm}_mean'] = df[tmp_lst].mean(axis=1)
        
    return df

df_eda = gen_avg_feats(df_eda, sensors_nm, lst_steps)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, sharey=True, figsize=(10,5))
fig.subplots_adjust(hspace=.4, wspace=.1)

sns.scatterplot(x='gen_hv_para3_std', y='y', data = df_eda, ax=axes[0,0], legend=False)
sns.scatterplot(x='gen_hv_para45_std', y='y', data = df_eda, ax=axes[0,1], legend=False)
sns.scatterplot(x='gen_pressure_para91_std', y='y',  data = df_eda, ax=axes[1,0], legend=False)
sns.scatterplot(x='gen_time_para5_std', y='y', data = df_eda, ax=axes[1,1], legend=False)
# Out:
# <AxesSubplot:xlabel='gen_time_para5_std', ylabel='y'>

# %%
param_set = set(x.split('_')[0].lower() for x in train_sensor['param_alias'])

# %%
def gen_avg_param(df):

        for i in param_set: # 파라미터가 들어가 있는 컬럼들
                
                param = [x for x in df.columns if i in x and 'para' in x]

                df[f'gen_avg_{i}'] = df[param].mean(axis=1)

        return df

# %%
def gen_avg_param(df):

        for i in param_set: # 파라미터가 들어가 있는 컬럼들
                
                param = [x for x in df.columns if i in x and 'para' in x]

                df[f'gen_avg_{i}'] = df[param].mean(axis=1)

        return df

def gen_std_param(df):

        for i in param_set: # 파라미터가 들어가 있는 컬럼들
                
                param = [x for x in df.columns if i in x and 'para' in x]

                df[f'gen_std_{i}'] = df[param].std(axis=1)

        return df

# %%
def gen_avg_step(df):

    for i in lst_steps:

        param_steps = [x for x in df.columns if i == x.split('_')[0] and 'para' in x]

        df[f'gen_avg_{i}'] = df[param_steps].mean(axis=1)

    return df

# %%
def log_skew(df):
    
    numeric = [k for k in df.columns if df[k].dtype == 'float']
    numeric_lst = pd.DataFrame(abs(df[numeric].skew())).sort_values(by = 0, ascending = False)[:100].index.tolist()
    
    for col in numeric_lst:

        if df[col].skew() < 0:
            df[col] = df[col] **2
        else:
            df[col] = df[col] ** 1/2

    return df

# %%
def cut_data(df, col):

    bins = [1400, 1450, 1520, 1570, 1660, 1750]
    labels = ['a', 'b', 'c', 'd', 'e']

    cuts = pd.cut(df[col], bins, right = False, labels = labels)
    
    return cuts

def cut_epd_data(df, col):
    
    bins_epd4 = [0, 50, 100]
    labels = ['a','b']

    cuts_efem = pd.cut(df[col], bins_epd4, right = False, labels = labels)

    return cuts_efem

# %%
sp_product = list(product(lst_steps, param_set))

step_params = ['_'.join(sp_product[i]) for i in range(len(sp_product))]

# %%
def gen_std_stpa(df):

    for step_param in step_params:

        step_param_cols = [x for x in lst_sensors[0] if step_param in x]

        df[f'gen_{step_param}_std'] =  df[step_param_cols].std(axis=1)

    return df

def gen_avg_stpa(df):

    for step_param in step_params:

        step_param_cols = [x for x in lst_sensors[0] if step_param in x]

        df[f'gen_{step_param}_avg'] =  df[step_param_cols].std(axis=1)

    return df
        
df_eda = gen_std_stpa(df_eda)
df_eda = gen_avg_stpa(df_eda)

# %%
# EDA를 위한 데이터 프레임 제거합니다.
del df_eda

# %% [markdown]
# <a name='04'></a>
# ## 4. 데이터 전처리
#
# 탐색적 데이터 분석을 통해 도출한 추가 변수를 생성(4.1절)합니다.
#
# 이상치 확인(4.2절), 분산이 적은 특징 제거(4.3절), 수치형 변수의 표준화(4.4절) 그리고 범주형 변수의 원-핫 인코딩(4.5절) 변환을 하여 데이터를 전처리합니다.

# %% [markdown]
# <a name='04-01'></a>
# ### 4.1 내부 데이터를 통한 변수 생성

# %%
# 전처리를 위한 학습용 데이터와 평가용 데이터를 복사합니다.
df_prep_train = train.copy()
df_prep_predict = predict.copy()

# %% [markdown]
# 탐색적 데이터 분석(3.3~3.5절)에서 분석한 결과를 활용해 새로운 특징을 생성합니다.
#
#
# *   모듈 이름의 상위 집계 단위를 나타내는 1개의 범주형 변수 (3.3절)
# *   전체 및 개별 공정 소요시간을 나타내는 7개의 변수(3.4절)
# *   센서 변수의 집약된 표준편차를 나타내는 95개의 변수 (3.5절)

# %%
# 모듈 이름의 상위 집계 단위를 나타내는 1개의 범주형 변수를 생성합니다(3.3절)
df_prep_train = gen_cate_feats(df_prep_train)
df_prep_predict = gen_cate_feats(df_prep_predict)

# %%
QQ_plot(df_prep_train['y'].clip(1240, 1500), 'y')

# %%
# y값 1240 이하 값 이상치 clip
df_prep_train['y']  = df_prep_train['y'].clip(1240, 1500)

# %%
# 전체 및 개별 공정 소요시간 7개의 변수를 생성합니다(3.4절)
df_prep_train = gen_duration_feats(df_prep_train, lst_stepsgap)
df_prep_predict = gen_duration_feats(df_prep_predict, lst_stepsgap)

# %%
# 센서 변수의 집약된 95개의 표준편차 변수를 생성합니다(3.5절)
df_prep_train = gen_stats_feats(df_prep_train, sensors_nm, lst_steps)
df_prep_predict = gen_stats_feats(df_prep_predict, sensors_nm, lst_steps)
df_prep_train.filter(regex='_std').head(2)
# Out:
#    gen_efem_para2_std  gen_efem_para25_std  gen_efem_para78_std  \
# 0            1.540604             1.487185             0.045480
# 1            1.313742             1.372572             0.045224
#
#    gen_epd_para4_std  gen_epd_para40_std  gen_epd_para63_std  \
# 0         377.964435            0.382780                 0.0
# 1         377.964435            0.462813                 0.0
#
#    gen_epd_para80_std  gen_esc_para84_std  gen_esc_para94_std  \
# 0                 0.0            0.000000                 0.0
# 1                 0.0            0.003024                 0.0
#
#    gen_fr_para28_std  ...  gen_time_para7_std  gen_time_para75_std  \
# 0        2926.724319  ...            0.163207             0.163356
# 1        2926.724319  ...            0.163207             0.165981
#
#    gen_time_para77_std  gen_time_para8_std  gen_time_para81_std  \
# 0             0.163356            0.163207             0.163356
# 1             0.165981            0.163211             0.165981
#
#    gen_time_para83_std  gen_time_para89_std  gen_time_para9_std  \
# 0             0.163207             0.163356            0.163207
# 1             0.163207             0.165981            0.163207
#
#    gen_time_para90_std  gen_tmp_para31_std
# 0             0.163356             0.54963
# 1             0.165981             0.55689
#
# [2 rows x 95 columns]

# %%
# 센서 변수의 집약된 95개의 평균 변수를 생성합니다
df_prep_train = gen_avg_feats(df_prep_train, sensors_nm, lst_steps)
df_prep_predict = gen_avg_feats(df_prep_predict, sensors_nm, lst_steps)

# %%
# 센서 변수의 왜도 첨도 값이 높은 값들 변환해주기
df_prep_train = log_skew(df_prep_train)
df_prep_predict = log_skew(df_prep_predict)

# %%
# Scatter Plot에 따른 전처리: 구간 별로 나눠줌

efem_para = [k for k in df_prep_train if ('efem_para2' in k) & ('gen' not in k)]

for col in efem_para:

    df_prep_train[f'cut_{col}'] = cut_data(df_prep_train, col)
    df_prep_predict[f'cut_{col}'] = cut_data(df_prep_predict, col)

df_prep_train['cut_06_epd_para4'] = cut_epd_data(df_prep_train, '06_epd_para4')
df_prep_predict['cut_06_epd_para4'] = cut_epd_data(df_prep_predict, '06_epd_para4')


gas_10_cols = [x for x in df_prep_train.columns if ('gas_para10' in x) & ('gen' not in x)]

for col in gas_10_cols:

    bins = [-0.01, -0.002, 0.002, 0.006, 1]

    labels = ['a','b','c','d']
    
    df_prep_train[f'cut_{col}'] = pd.cut(df_prep_train[col], bins, right = False, labels = labels)
    df_prep_predict[f'cut_{col}'] = pd.cut(df_prep_predict[col], bins, right = False, labels = labels)

gas_19_cols = [x for x in df_prep_train.columns if ('gas_para19' in x) & ('gen' not in x)]

for col in gas_19_cols:

    bins = [-0.01, -0.008, -0.006, -0.004, -0.001, 0.001, 0.003, 1]

    labels = ['a','b','c','d','e','f','g']
    
    df_prep_train[f'cut_{col}'] = pd.cut(df_prep_train[col], bins, right = False, labels = labels)
    df_prep_predict[f'cut_{col}'] = pd.cut(df_prep_predict[col], bins, right = False, labels = labels)

bins = [0.2, 0.255, 0.265, 0.275, 0.3]

labels = ['a','b','c','d']

df_prep_train['cut_20_hv_para3'] = pd.cut(df_prep_train['20_hv_para3'], bins, right = False, labels = labels)
df_prep_predict['cut_20_hv_para3'] = pd.cut(df_prep_predict['20_hv_para3'], bins, right = False, labels = labels)

# %%
# 두 구간으로 나누는 변수 처리
def cut_2(df, col):
    bins = [0, 0.4, 1.0]
    labels = ['A', 'B']

    cuts = pd.cut(df[col], bins, right = False, labels = labels)
    return cuts

#hv 변수 처리
def cut_hv_data(df, col):
    bins = [-2.5, -0.8, 0.5, 2.5]
    labels = ['A', 'B', 'C']

    cuts = pd.cut(df[col], bins, right = False, labels = labels)
    
    return cuts

# he 변수 처리
he_175 = ['04_he_para88', '06_he_para88']
he_30 = ['12_he_para88', '13_he_para88', '17_he_para88', '20_he_para88']

for h1 in he_175:
    df_prep_train[h1]  = df_prep_train[h1].clip(0, 1.75)
    df_prep_predict[h1] = df_prep_predict[h1].clip(0, 1.75)

for h2 in he_30:
    df_prep_train[h2] = df_prep_train[h2].clip(0, 3.0)
    df_prep_predict[h2] = df_prep_predict[h2].clip(0, 3.0)

# fr 변수 처리
cut_01 = ['06_epd_para4', '17_fr_para35', '20_fr_para35']

for cut in cut_01:
    df_prep_train[f'cut_{cut}'] = cut_2(df_prep_train, cut)
    df_prep_predict[f'cut_{cut}'] = cut_2(df_prep_predict, cut)

# time 변수 추가 처리

time_para = ['04', '06', '12', '13', '17', '18', '20']
for time in time_para:
    df_prep_train[f'{time}_time_para16'] = df_prep_train[f'{time}_time_para16'].clip(0, 5000)
    df_prep_predict[f'{time}_time_para16'] = df_prep_predict[f'{time}_time_para16'].clip(0, 5000)

for h1 in he_175:
    df_prep_train[h1]  = df_prep_train[h1].clip(0, 1.75)
    df_prep_predict[h1] = df_prep_predict[h1].clip(0, 1.75)

for h2 in he_30:
    df_prep_train[h2] = df_prep_train[h2].clip(0, 3.0)
    df_prep_predict[h2] = df_prep_predict[h2].clip(0, 3.0)

# %%
# 타겟 변수에 대해 log변환
def log_transform(df,feat_nm):

    df[f'log_{feat_nm}'] = np.log1p(df[feat_nm])

    df.drop(feat_nm, axis=1, inplace=True)

    return df

# df_prep_train = log_transform(df_prep_train, 'y')

# %%
# 870초를 기준으로 일찍 마친 장비와 늦께 마친 장비를 구분합니다.
df_prep_train.loc[df_prep_train['gen_tmdiff'] < 1870, 'tmdiff_speed'] = 'E' # Early 
df_prep_train.loc[df_prep_train['gen_tmdiff'] > 1870, 'tmdiff_speed'] = 'L' # Late

df_prep_predict.loc[df_prep_predict['gen_tmdiff'] < 1870, 'tmdiff_speed'] = 'E' # Early 
df_prep_predict.loc[df_prep_predict['gen_tmdiff'] > 1870, 'tmdiff_speed'] = 'L' # Late

# %% [markdown]
# <a name='04-02'></a>
# ### 4.2 이상치 치환하기
#
# 분위점을 임계값으로 삼아 이상치를 치환합니다.
#
# 학습 데이터의 1%점을 하한, 99%점을 상한으로 잡고 해당 범위를 벗어나는 값을 각각 **하한값과 상한값으로 치환**합니다.

# %%
# 이상치 확인을 위한 데이터 복사 
df_outlier = df_prep_train.copy()

# %%
def outlier(x, p01, p99):

    if x < p01 or x > p99:
        return 'Y'
    else:
        return 'N'

# 특정 컬럼의 이상치를 확인해봅니다. 
tmp_lst = ['04_fr_para35', '04_gas_para36', '04_fr_para28', '04_temp_para66']


for col in tmp_lst:

    q1 = df_outlier[col].quantile(0.25) 
    q3 = df_outlier[col].quantile(0.75) 

    iqr=q3-q1

    low_lim = q3 + 1.5 * iqr
    high_lim = q1 - 1.5 * iqr

    df_outlier[f'{col}_outlier'] = df_outlier[col].apply(outlier, args=(low_lim, high_lim))

# %% [markdown]
# 상한값과 하한값을 벗어나는 데이터 포인트를 확인합니다.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, sharey=True, figsize=(10,5))
fig.subplots_adjust(hspace=.4, wspace=.1)

sns.scatterplot(x='04_fr_para35', y='y', hue='04_fr_para35_outlier', data = df_outlier, ax=axes[0,0], legend=False)
sns.scatterplot(x='04_gas_para36', y='y', hue='04_gas_para36_outlier', data = df_outlier, ax=axes[0,1])
sns.scatterplot(x='04_fr_para28', y='y',  hue='04_fr_para28_outlier', data = df_outlier, ax=axes[1,0], legend=False)
sns.scatterplot(x='04_temp_para66', y='y', hue='04_temp_para66_outlier', data = df_outlier, ax=axes[1,1], legend=False)
axes[0,1].legend(loc='lower left', ncol=1, title='Outlier', bbox_to_anchor=(1.04, -0.5))

# %%
# 기존 센서 변수(665개)와 생성 변수 중 수치형 변수(102개) 컬럼을 정의합니다. 
col_numerical = col_sensor + df_prep_train.filter(regex='^gen_').columns.tolist()

# %%
def cliping(df,columns):
    
    for col in columns:

        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)

        iqr = q3 - q1

        low_lim = q3 + 1.5 * iqr
        high_lim = q1 - 1.5 * iqr

        df[col] = df[col].clip(low_lim, high_lim)

    return df

df_prep_train = cliping(df_prep_train, col_numerical)
df_prep_predict = cliping(df_prep_predict, col_numerical)

# %% [markdown]
# 이상치 처리후 결과를 확인합니다.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, sharey=True, figsize=(10,5))
fig.subplots_adjust(hspace=.4, wspace=.1)

sns.scatterplot(x='04_fr_para35', y='y', data = df_prep_train, ax=axes[0,0])
sns.scatterplot(x='04_gas_para36', y='y', data = df_prep_train, ax=axes[0,1])
sns.scatterplot(x='04_fr_para28', y='y',  data = df_prep_train, ax=axes[1,0])
sns.scatterplot(x='04_temp_para66', y='y', data = df_prep_train, ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='04_temp_para66', ylabel='y'>

# %% [markdown]
# <a name='04-03'></a>
# ### 4.3 분산이 적은 변수 제거
# 분산 기준 설정(Variance Thresholding)은 가장 기본적인 특성 선택 방법 중 하나입니다.
#
# 분산이 0 인 특징은 정보가 없으므로 해당 특징을 삭제합니다.

# %%
# threshold 인자를 변경하여 분산의 기준값을 수동으로 선택할 수 있습니다.
thresholder = VarianceThreshold(threshold=0)
_ = thresholder.fit_transform(df_prep_train[col_numerical])

 # 분산이 0이면 True 이므로 제거할 컬럼을 추출합니다.  
mask = ~thresholder.get_support()
cols_var_drop = np.asarray(col_numerical)[mask].tolist()
print(f'** {len(cols_var_drop)} Features to Drop by Low Variance')
print(f'{cols_var_drop}')
# Out:
# ** 218 Features to Drop by Low Variance
# ['04_epd_para4', '04_epd_para40', '04_epd_para63', '04_epd_para80', '04_esc_para84', '04_fr_para28', '04_fr_para35', '04_fr_para69', '04_gas_para10', '04_gas_para13', '04_gas_para19', '04_gas_para27', '04_gas_para39', '04_gas_para46', '04_gas_para48', '04_gas_para50', '04_gas_para70', '04_gas_para71', '04_gas_para74', '04_he_para1', '04_he_para95', '04_power_para14', '04_power_para49', '04_power_para57', '04_power_para68', '04_power_para82', '04_temp_para24', '04_time_para5', '06_epd_para4', '06_epd_para63', '06_epd_para80', '06_esc_para84', '06_fr_para28', '06_fr_para35', '06_fr_para69', '06_gas_para10', '06_gas_para13', '06_gas_para15', '06_gas_para19', '06_gas_para27', '06_gas_para39', '06_gas_para46', '06_gas_para48', '06_gas_para50', '06_gas_para51', '06_gas_para70', '06_gas_para74', '06_gas_para85', '06_he_para1', '06_he_para95', '06_hv_para3', '06_hv_para45', '06_hv_para47', '06_hv_para56', '06_power_para14', '06_power_para68', '06_power_para82', '06_temp_para24', '06_time_para5', '12_epd_para4', '12_epd_para40', '12_epd_para63', '12_epd_para80', '12_esc_para84', '12_esc_para94', '12_fr_para28', '12_fr_para69', '12_gas_para10', '12_gas_para15', '12_gas_para19', '12_gas_para39', '12_gas_para48', '12_gas_para50', '12_gas_para51', '12_gas_para70', '12_gas_para71', '12_gas_para85', '12_he_para1', '12_he_para95', '12_power_para49', '12_power_para57', '12_power_para68', '12_temp_para17', '12_temp_para23', '12_temp_para54', '12_temp_para92', '13_epd_para4', '13_epd_para40', '13_epd_para63', '13_epd_para80', '13_esc_para84', '13_esc_para94', '13_fr_para28', '13_fr_para35', '13_fr_para69', '13_gas_para10', '13_gas_para15', '13_gas_para19', '13_gas_para39', '13_gas_para50', '13_gas_para70', '13_gas_para71', '13_gas_para74', '13_gas_para85', '13_he_para1', '13_he_para95', '13_power_para49', '13_power_para57', '13_power_para68', '13_temp_para17', '13_temp_para23', '13_temp_para54', '13_temp_para66', '13_temp_para92', '17_epd_para4', '17_epd_para40', '17_epd_para63', '17_epd_para80', '17_esc_para84', '17_esc_para94', '17_fr_para28', '17_fr_para69', '17_gas_para10', '17_gas_para15', '17_gas_para19', '17_gas_para39', '17_gas_para48', '17_gas_para50', '17_gas_para51', '17_gas_para70', '17_gas_para71', '17_gas_para85', '17_he_para1', '17_he_para95', '17_power_para49', '17_power_para57', '17_power_para68', '17_temp_para17', '17_temp_para23', '17_temp_para54', '17_temp_para66', '18_epd_para4', '18_epd_para40', '18_epd_para63', '18_epd_para80', '18_esc_para84', '18_esc_para94', '18_fr_para28', '18_fr_para69', '18_gas_para10', '18_gas_para15', '18_gas_para19', '18_gas_para39', '18_gas_para50', '18_gas_para70', '18_gas_para71', '18_gas_para74', '18_gas_para85', '18_he_para1', '18_he_para95', '18_power_para49', '18_power_para57', '18_power_para68', '18_temp_para17', '18_temp_para23', '18_temp_para54', '18_temp_para66', '20_epd_para4', '20_epd_para40', '20_epd_para63', '20_epd_para80', '20_esc_para84', '20_fr_para28', '20_fr_para69', '20_gas_para10', '20_gas_para15', '20_gas_para19', '20_gas_para48', '20_gas_para51', '20_gas_para70', '20_gas_para71', '20_gas_para74', '20_gas_para85', '20_he_para1', '20_he_para95', '20_hv_para45', '20_hv_para47', '20_power_para49', '20_power_para57', '20_power_para68', '20_temp_para54', 'gen_tmdiff_1213', 'gen_tmdiff_1718', 'gen_epd_para4_std', 'gen_epd_para63_std', 'gen_epd_para80_std', 'gen_esc_para84_std', 'gen_fr_para28_std', 'gen_fr_para69_std', 'gen_gas_para10_std', 'gen_gas_para19_std', 'gen_gas_para48_std', 'gen_gas_para70_std', 'gen_he_para1_std', 'gen_he_para95_std', 'gen_power_para68_std', 'gen_epd_para4_mean', 'gen_epd_para63_mean', 'gen_epd_para80_mean', 'gen_esc_para84_mean', 'gen_fr_para28_mean', 'gen_fr_para69_mean', 'gen_gas_para10_mean', 'gen_gas_para19_mean', 'gen_gas_para70_mean', 'gen_he_para1_mean', 'gen_he_para95_mean', 'gen_power_para68_mean']

# %% [markdown]
# 분산이 0인 특징에 대해 확인해보겠습니다.

# %%
sns.scatterplot(x=cols_var_drop[0], y='y', data=df_prep_train)
# Out:
# <AxesSubplot:xlabel='04_epd_para4', ylabel='y'>

# %% [markdown]
# <a name='04-05'></a>
# ### 4.5 원-핫 인코딩
#
# **module_name_eq** 는 문자열로 나타난 범주형 변수입니다.
#
# 범주형 변수의 대표적인 변환 기법인 원-핫 인코딩을 사용하여 변환합니다.

# %%
col_cut = df_prep_train.filter(regex = '^cut').columns.tolist()

# %%
def prep_cate_feats(df_tr, df_te, feat_nm):

    df_merge = pd.concat([df_tr, df_te])

    # 컬럼명과 범주형 변수의 레벨명을 이용한 새로운 컬럼명을 자동생성합니다. 
    # ex. module_name_eq -> module_name_eq_EQ01, module_name_eq_EQ02, etc.
    df_merge = pd.get_dummies(df_merge, columns=[feat_nm])

    df_tr = df_merge.iloc[:df_tr.shape[0], :].reset_index(drop=True)
    df_te = df_merge.iloc[df_tr.shape[0]:, :].reset_index(drop=True)

    return df_tr, df_te

# module_name_eq 의 원-핫 인코딩 변수를 생성합니다.
df_prep_train, df_prep_predict = prep_cate_feats(df_prep_train, df_prep_predict, 'module_name_eq')

for col in col_cut:
    df_prep_train, df_prep_predict = prep_cate_feats(df_prep_train, df_prep_predict, col)

# %%
df_prep_train, df_prep_predict = prep_cate_feats(df_prep_train, df_prep_predict, 'tmdiff_speed')

# %% [markdown]
# ### 다중공선성(VIF)

# %%
df_prep_train.dropna(axis=1, inplace=True)
df_prep_predict.dropna(axis=1, inplace=True)

# %%
## 다중공선성 VIF 확인
# VIF 출력을 위한 데이터 프레임 형성
vif = pd.DataFrame()
idx_numerical = [col for col in df_prep_train.columns if (df_prep_train[col].dtype == 'float') & ('y' not in col)]

# VIF 값과 각 Feature 이름에 대해 설정
vif["VIF Factor"] = [variance_inflation_factor(df_prep_train[idx_numerical].values, i) for i in range(df_prep_train[idx_numerical].shape[1])]
vif["features"] = df_prep_train[idx_numerical].columns

# VIF 값이 높은 순으로 정렬
vif = vif.sort_values(by="VIF Factor", ascending=False)
vif = vif.reset_index().drop(columns='index')
vif
# Out:
#        VIF Factor               features
# 0    8.378790e+12          13_time_para7
# 1    2.705677e+12         12_time_para16
# 2    1.576063e+12          18_time_para9
# 3    1.005425e+11         12_time_para81
# 4    9.856753e+10           20_fr_para61
# ..            ...                    ...
# 871           NaN    gen_epd_para63_mean
# 872           NaN    gen_epd_para80_mean
# 873           NaN    gen_gas_para10_mean
# 874           NaN    gen_gas_para19_mean
# 875           NaN  gen_power_para68_mean
#
# [876 rows x 2 columns]

# %%
vif_10 = vif[vif['VIF Factor'] > 10]
print(len(vif_10))
print(len([fea for fea in vif_10['features'] if ('mean' not in fea) & ('std' not in fea) & ('avg' not in fea) & ('time' not in fea)&('log_y' not in fea)]))

vif_10_lst = [fea for fea in vif_10['features'] if ('mean' not in fea) & ('std' not in fea) & ('avg' not in fea) & ('time' not in fea)&('log_y' not in fea)]
# Out:
# 581
# 284

# %%
# PCA 처리
pca = PCA(n_components=len(vif_10_lst))

x_train_pca = pca.fit(df_prep_train[vif_10_lst])
x_predict_pca = pca.transform(df_prep_predict[vif_10_lst])

pca_result = pd.DataFrame({'설명 가능한 분산 비율':pca.explained_variance_, '기여율' : pca.explained_variance_ratio_})

# %%
pca_result['누적기여율'] = pca_result['기여율'].cumsum()
# 누적 기여율이 80%가 넘어가는 지점까지 적용

# %%
plt.figure(figsize = (5, 3))
sns.lineplot(x = pca_result.index, y = '설명 가능한 분산 비율', data = pca_result)
# 보통 완만해지는 부분까지 PCA 개수 선정
# Out:
# <AxesSubplot:ylabel='설명 가능한 분산 비율'>

# %%
pca = PCA(n_components=2)

x_train_pca = pca.fit_transform(df_prep_train[vif_10_lst])
x_predict_pca = pca.transform(df_prep_predict[vif_10_lst])

# %%
pca_train = pd.DataFrame(x_train_pca, columns = [f'pca_{col}' for col in vif_10_lst[:2]])
pca_predict = pd.DataFrame(x_predict_pca, columns = [f'pca_{col}' for col in vif_10_lst[:2]])

# %%
df_prep_train = pd.concat([df_prep_train, pca_train], axis = 1)
df_prep_predict = pd.concat([df_prep_predict, pca_predict], axis = 1)

# %%
df_prep_train.drop(vif_10_lst, axis = 1, inplace = True)
df_prep_predict.drop(vif_10_lst, axis =1 , inplace = True)

# %% [markdown]
# <a name='04-06'></a>
# ### 4.6 변수 선택
#
# 변수 선택은 주어진 데이터의 변수 중에서 모델링의 가장 적절한 변수만 선택하는 과정입니다.
#
# 변수 선택 방법은 필터 방법(Filter method), 래퍼 방법(Wrapper method), 임베디드 방법(Embeded method)이 있습니다.
#
# - **필터 방법** : 통계량(ex. 상관계수, 카이제곱, 상호정보량)을 구하여 가장 뛰어난 특성을 선택하는 기법 (ex. SelectKBest)
# - **래퍼 방법** : 시행착오를 통해 가장 높은 품질의 예측을 만드는 특성의 부분조합을 찾는 기법 (ex. RFE, RFECV)
# - **임베디드 방법** : 결정트리 모델로부터 생성된 특징 중요도를 이용하여 특성을 선택하는 기법 (ex. SelectFromModel)
#
# 다음은 필터 방법중 상호정보량을 사용하여 중요 특성을 추출하는 예제코드입니다.
#
# 참가자들은 자유롭게 분석하며, 변수 선택 중 한가지 방법으로 참고할 수 있습니다.

# %%
col_numerical = col_sensor + df_prep_train.filter(regex='^gen_').columns.tolist()

# %%
col_numeric =  set([k for k in df_prep_train.columns if (df_prep_train[k].dtype == 'float') & ('y' not in k)] + df_prep_train.filter(regex='^gen_').columns.tolist())

# %%
len(col_numeric)
# Out:
# 594

# %%
skb = SelectKBest(score_func=mutual_info_regression, k=250) 
skb.fit(df_prep_train[col_numeric], df_prep_train['y'])
select_features_kbest = skb.get_support()
col_featsIDX = pd.Index(df_prep_train[col_numeric].columns.tolist())
col_selected_mutual = col_featsIDX[select_features_kbest]

# %% [markdown]
# <a name='05'></a>
# ## 5. 모델링

# %% [markdown]
# <a name='05-01'></a>
# ### 5.1 데이터 분할
#
# 모델의 일반화 성능을 평가하기 위해 학습 데이터 중 일부를 검증용 데이터로 분할합니다.
#
# train_test_split 함수를 이용하여 학습용 데이터 중 10% 데이터를 검증 데이터로 분류합니다.

# %%
# 학습에 사용할 수치형 변수 컬럼을 정의합니다. 
# 앞서 정의한 col_numerical 에서 분산이 0 인 컬럼을 제거합니다.
col_numerical = [col for col in col_selected_mutual if col not in cols_var_drop]
# 학습에 사용할 원-핫 인코딩된 범주형 변수 컬럼을 정의합니다. 
col_cate_module_name_eq = df_prep_train.filter(regex='module_name_eq').columns.tolist()
col_cut_ohe = df_prep_train.filter(regex = '^cut').columns.tolist()
# 모델에 입력으로 사용될 최종 컬럼을 정의합니다.
col_X = col_numerical + col_cate_module_name_eq + col_cut_ohe
col_y = 'y'

# 학습용 데이터를 정의합니다.
x_train_raw = df_prep_train[col_X]
y_train_raw = df_prep_train[col_y]
# 평가용 데이터를 정의합니다.
x_predict = df_prep_predict[col_X]
# 학습 데이터 중 일부를 검증 데이터 셋으로 분할합니다.
x_train,x_test,y_train,y_test = train_test_split(x_train_raw, y_train_raw, test_size=0.2,random_state=1)
x_train_,x_valid,y_train_,y_valid = train_test_split(x_train, y_train, test_size=0.2,random_state=1)

print(x_train.shape,y_train.shape)
print(x_train_.shape,y_train_.shape)
print(x_valid.shape,y_valid.shape)
print(x_test.shape,y_test.shape)
# Out:
# (488, 418) (488,)
# (390, 418) (390,)
# (98, 418) (98,)
# (123, 418) (123,)

# %% [markdown]
# #### 데이터 증강

# %%
os_df = x_train_.join(y_train_, how='left')

# %%
QQ_plot(os_df['y'], 'y')

# %%
len(os_df[os_df['y'] > 1283])
# Out:
# 3

# %%
os_df.loc[os_df['y'] < 1242, 'y_cate'] = 'A'
os_df.loc[(os_df['y'] >= 1242)&(os_df['y'] <= 1283), 'y_cate'] = 'B'
os_df.loc[os_df['y'] > 1283, 'y_cate'] = 'C'

# %%
os_df['log_y'] = np.log1p(os_df['y']) 
y_test = np.log1p(y_test)
y_valid = np.log1p(y_valid)

# %%
os_df, os_target = RandomOverSampler(random_state=1).fit_resample(os_df.drop('y_cate',axis=1), os_df['y_cate'])

# %%
os_df.drop('y',axis=1,inplace=True)

# %%
x_train_ = os_df[os_df.columns[:x_train_.shape[1]]]
y_train_ = os_df[os_df.columns[-1]]

print(x_train.shape,y_train.shape)
print(x_train_.shape,y_train_.shape)
print(x_valid.shape,y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (488, 418) (488,)
# (1149, 418) (1149,)
# (98, 418) (98,)
# (123, 418) (123,)

# %% [markdown]
# 학습 데이터 셋 표준화

# %%
scaler = StandardScaler()
# 학습 데이터 각 변수의 평균값과 표준편차를 저장한 후, 이를 사용하여 학습 및 평가용 데이터를 변환합니다.
x_train_[col_numerical] = scaler.fit_transform(x_train_[col_numerical])
x_valid[col_numerical] = scaler.transform(x_valid[col_numerical])

# %% [markdown]
# 모델의 성능 평가를 위해 제곱근평균제곱오차(RMSE)를 반환하는 함수를 작성합니다.

# %%
# mean_squared_error 의 매개변수 squared 가 False 이면 RMSE 를 반환합니다.
def rmse(y_true,y_pred):

    return round(mean_squared_error(y_true, y_pred,squared=False),4)

# %%
os_df.iloc[:,-1]
# Out:
# 0       7.132763
# 1       7.147138
# 2       7.145502
# 3       7.134803
# 4       7.146741
#           ...
# 1144    7.161715
# 1145    7.160055
# 1146    7.160258
# 1147    7.160055
# 1148    7.160055
# Name: log_y, Length: 1149, dtype: float64

# %% [markdown]
# # 모델링

# %% [markdown]
# <a name='05-02'></a>
# ### 5.2 릿지 회귀 모델
# 선형 모델 중 하나인 릿지 모델을 사용합니다. 릿지 모델은 계수의 제곱에 비례하여 벌칙을 부여하는 **L2 정규화**를 사용합니다.
#
# 릿지 회귀 모델에서 튜닝해야할 매개변수는 정규화의 세기를 나타내는 **alpha** 입니다.

# %%
# 평가 함수 정의
def evaluate_ridge(alpha):
    model = Ridge(alpha=alpha)
    model.fit(x_train_, y_train_)
    score = model.score(x_train_, y_train_)
    return score

# 베이지안 최적화 모델 구성
bounds = {'alpha': (0, 10)}
optimizer = BayesianOptimization(f=evaluate_ridge, pbounds=bounds, random_state=42)

# 최적화
optimizer.maximize(init_points=5, n_iter=20)

# 최적 alpha 추론
alpha = optimizer.max['params']['alpha']
print('Optimal alpha:', alpha)

# 최적 alpha로 학습된 모델 생성
ridge_model = Ridge(alpha=alpha)
ridge_model.fit(x_train_, y_train_)

# 파라미터 출력
print('Coefficients:', ridge_model.coef_)
print('Intercept:', ridge_model.intercept_)
# Out:
# |   iter    |  target   |   alpha   |
# -------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vm/qw01phdd0gvfvb6qnb3_bk680000gn/T/ipykernel_6676/510531552.py in <module>
#      11
#      12 # 최적화
# ---> 13 optimizer.maximize(init_points=5, n_iter=20)
#      14
#      15 # 최적 alpha 추론
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acquisition_function, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     309                 x_probe = self.suggest(util)
#     310                 iteration += 1
# --> 311             self.probe(x_probe, lazy=False)
#     312
#     313             if self._bounds_transformer and iteration > 0:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bayes_opt/bayesian_optimization.py in probe(self, params, lazy)
#     206             self._queue.add(params)
#     207         else:
# --> 208             self._space.probe(params)
#     209             self.dispatch(Events.OPTIMIZATION_STEP)
#     210
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bayes_opt/target_space.py in probe(self, params)
#     234         x = self._as_array(params)
#     235         params = dict(zip(self._keys, x))
# --> 236         target = self.target_func(**params)
#     237
#     238         if self._constraint is None:
#
# /var/folders/vm/qw01phdd0gvfvb6qnb3_bk680000gn/T/ipykernel_6676/510531552.py in evaluate_ridge(alpha)
#       3     model = Ridge(alpha=alpha)
#       4     model.fit(x_train_[col_numerical], y_train_)
# ----> 5     score = model.score(x_train_, y_train_)
#       6     return score
#       7
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     703         from .metrics import r2_score
#     704
# --> 705         y_pred = self.predict(X)
#     706         return r2_score(y, y_pred, sample_weight=sample_weight)
#     707
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     343         check_is_fitted(self)
#     344
# --> 345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     347
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     583
#     584         if not no_val_X and check_params.get("ensure_2d", True):
# --> 585             self._check_n_features(X, reset=reset)
#     586
#     587         return out
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     398
#     399         if n_features != self.n_features_in_:
# --> 400             raise ValueError(
#     401                 f"X has {n_features} features, but {self.__class__.__name__} "
#     402                 f"is expecting {self.n_features_in_} features as input."
#
# ValueError: X has 418 features, but Ridge is expecting 249 features as input.

# %% [markdown]
# <a name="05-03"></a>
# ### 5.3 랜덤 포레스트 모델
# 랜덤 포레스트는 행 데이터를 샘플링한 후, 병렬로 수행된 다수의 결정 트리로부터 예측한 평균값을 출력합니다.
#
# 랜덤 포레스트에서 튜닝해야할 변수는 다음과 같습니다.
#
# *  n_estimators : 결정 트리 갯수 ( default : 100 )
# *  max_depth : 트리의 최대 깊이 ( default : None )
# *  min_samples_split : 노드를 분할하기 위한 최소 샘플 갯수 ( default : 2 )
# *  min_samples_leaf : 리프 노드가 되기 위한 최소 샘플 갯수 ( default : 1 )
# *  max_features : 각 노드에서 분기시 사용할 최대 특성 갯수 ( default : 1.0 - 전체 특성 갯수 )
# *  bootstrap : 중복을 허용한 샘플링 여부 ( default : True )
#
#
# 결정 트리의 갯수가 커질수록 계산시간이 증가하므로, 시간과 성능의 트레이드 오프로 결정합니다.

# %%
def rf_cv(n_estimators, min_samples_split, max_features, max_depth):
    val = cross_val_score(
        RandomForestRegressor(n_estimators=int(n_estimators),
            min_samples_split=int(min_samples_split),
            
            max_features=min(max_features, 0.999), # float
            max_depth=int(max_depth),
            random_state=42
        ),
        x_train[col_numerical], y_train, scoring='neg_mean_squared_error', cv=10  #.iloc[:,0]
    )
    val=np.nan_to_num(val)
    val = val.mean()
    return val

# %%
rf_bo = BayesianOptimization(
        rf_cv,
        {'n_estimators': (200, 1000),
        'min_samples_split': (2, 20),
        'max_features': (0.1, 0.999),
        'max_depth': (5, 15)}
    )

# %%
# rf_bo.maximize()

# %%
# rf_bo.max #최적해

# %% [markdown]
# {'target': -58.42776901627455,
#  'params': {'max_depth': 10.639942346522895,
#   'max_features': 0.1,
#   'min_samples_split': 6.214519214831656,
#   'n_estimators': 689.5962047418285}}

# %%
rf_model = RandomForestRegressor(max_depth= 11,
  max_features=0.1,
  min_samples_split= 6,
  n_estimators= 690) 
rf_model.fit(x_train_,y_train_)
# Out:
# RandomForestRegressor(max_depth=11, max_features=0.1, min_samples_split=6,
#                       n_estimators=690)

# %%
# log 단위(1e+01)로 1.e-02 ~ 1.e+01 구간에 대해 매개변수를 탐색합니다
# solver_list = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']

# %% [markdown]
# <a name="05-04"></a>
# ### 5.4 CatboostRegressor

# %%
from sklearn.model_selection import KFold
from catboost import CatBoostRegressor, Pool

# %%
def ca_cv(learning_rate, max_depth,l2_leaf_reg,random_strength):
    val = cross_val_score(
        CatBoostRegressor(
            learning_rate=int(learning_rate),
            max_depth=int(max_depth),
            l2_leaf_reg=int(l2_leaf_reg),
            random_strength=random_strength,
             loss_function='RMSE',
        eval_metric='RMSE',
        verbose=False,
        
            
            random_state=42
        ),
        x_train[col_numerical], y_train, scoring='neg_mean_squared_error', cv=10  
    )
    val=np.nan_to_num(val)
    val = val.mean()
    return val

# %%
ca_bo = BayesianOptimization(
        ca_cv,
        {'learning_rate': (0.01, 0.2),
    'max_depth': (4, 10),
    'l2_leaf_reg': (1, 10),
    'random_strength': (0, 1)
    # 'loss_function': 'RMSE',
    # 'eval_metric': 'RMSE',
    # 'verbose':  False,
    
        }
    )

# %%
ca_bo.max

# %% [markdown]
# {'target': 0.0,
#  'params': {'l2_leaf_reg': 6.923354233523075,
#   'learning_rate': 0.17901079154275465,
#   'max_depth': 6.400915453521564,
#   'random_strength': 0.5122754399465809}}

# %%
cbr_model = CatBoostRegressor(l2_leaf_reg=7,learning_rate=0.1,max_depth=6,random_strength=1)
cbr_model.fit(x_train_,y_train_)
# Out:
# 0:	learn: 0.0141861	total: 80.8ms	remaining: 1m 20s
# 1:	learn: 0.0129769	total: 86.8ms	remaining: 43.3s
# 2:	learn: 0.0118669	total: 92.7ms	remaining: 30.8s
# 3:	learn: 0.0108921	total: 98.4ms	remaining: 24.5s
# 4:	learn: 0.0099845	total: 106ms	remaining: 21.1s
# 5:	learn: 0.0091655	total: 112ms	remaining: 18.6s
# 6:	learn: 0.0084496	total: 119ms	remaining: 16.8s
# 7:	learn: 0.0078039	total: 125ms	remaining: 15.5s
# 8:	learn: 0.0072302	total: 132ms	remaining: 14.5s
# 9:	learn: 0.0067101	total: 138ms	remaining: 13.7s
# 10:	learn: 0.0062472	total: 145ms	remaining: 13s
# 11:	learn: 0.0058249	total: 151ms	remaining: 12.4s
# 12:	learn: 0.0054725	total: 157ms	remaining: 11.9s
# 13:	learn: 0.0051604	total: 162ms	remaining: 11.4s
# 14:	learn: 0.0048644	total: 168ms	remaining: 11.1s
# 15:	learn: 0.0046241	total: 174ms	remaining: 10.7s
# 16:	learn: 0.0044146	total: 180ms	remaining: 10.4s
# 17:	learn: 0.0042233	total: 186ms	remaining: 10.1s
# 18:	learn: 0.0040634	total: 193ms	remaining: 9.95s
# 19:	learn: 0.0039245	total: 200ms	remaining: 9.79s
# 20:	learn: 0.0038027	total: 206ms	remaining: 9.58s
# 21:	learn: 0.0036943	total: 213ms	remaining: 9.45s
# 22:	learn: 0.0035942	total: 218ms	remaining: 9.27s
# 23:	learn: 0.0035145	total: 224ms	remaining: 9.11s
# 24:	learn: 0.0034451	total: 230ms	remaining: 8.97s
# 25:	learn: 0.0033768	total: 236ms	remaining: 8.83s
# 26:	learn: 0.0033107	total: 242ms	remaining: 8.71s
# 27:	learn: 0.0032540	total: 248ms	remaining: 8.6s
# 28:	learn: 0.0032069	total: 253ms	remaining: 8.48s
# 29:	learn: 0.0031605	total: 259ms	remaining: 8.38s
# 30:	learn: 0.0031223	total: 265ms	remaining: 8.28s
# 31:	learn: 0.0030840	total: 271ms	remaining: 8.19s
# 32:	learn: 0.0030479	total: 277ms	remaining: 8.11s
# 33:	learn: 0.0030208	total: 284ms	remaining: 8.05s
# 34:	learn: 0.0029987	total: 290ms	remaining: 7.99s
# 35:	learn: 0.0029777	total: 296ms	remaining: 7.92s
# 36:	learn: 0.0029561	total: 302ms	remaining: 7.87s
# 37:	learn: 0.0029347	total: 309ms	remaining: 7.82s
# 38:	learn: 0.0029172	total: 315ms	remaining: 7.75s
# 39:	learn: 0.0029059	total: 320ms	remaining: 7.69s
# 40:	learn: 0.0028898	total: 327ms	remaining: 7.64s
# 41:	learn: 0.0028812	total: 333ms	remaining: 7.6s
# 42:	learn: 0.0028675	total: 340ms	remaining: 7.56s
# 43:	learn: 0.0028563	total: 346ms	remaining: 7.51s
# 44:	learn: 0.0028343	total: 352ms	remaining: 7.47s
# 45:	learn: 0.0028189	total: 358ms	remaining: 7.42s
# 46:	learn: 0.0028054	total: 364ms	remaining: 7.37s
# 47:	learn: 0.0027924	total: 369ms	remaining: 7.33s
# 48:	learn: 0.0027768	total: 375ms	remaining: 7.29s
# 49:	learn: 0.0027582	total: 381ms	remaining: 7.24s
# 50:	learn: 0.0027358	total: 387ms	remaining: 7.21s
# 51:	learn: 0.0027264	total: 393ms	remaining: 7.17s
# 52:	learn: 0.0027122	total: 399ms	remaining: 7.13s
# 53:	learn: 0.0026979	total: 405ms	remaining: 7.1s
# 54:	learn: 0.0026873	total: 412ms	remaining: 7.07s
# 55:	learn: 0.0026717	total: 418ms	remaining: 7.04s
# 56:	learn: 0.0026604	total: 423ms	remaining: 7s
# 57:	learn: 0.0026487	total: 430ms	remaining: 6.98s
# 58:	learn: 0.0026388	total: 436ms	remaining: 6.96s
# 59:	learn: 0.0026311	total: 442ms	remaining: 6.92s
# 60:	learn: 0.0026247	total: 448ms	remaining: 6.9s
# 61:	learn: 0.0026116	total: 455ms	remaining: 6.88s
# 62:	learn: 0.0025995	total: 461ms	remaining: 6.86s
# 63:	learn: 0.0025906	total: 467ms	remaining: 6.84s
# 64:	learn: 0.0025800	total: 473ms	remaining: 6.8s
# 65:	learn: 0.0025677	total: 480ms	remaining: 6.79s
# 66:	learn: 0.0025494	total: 486ms	remaining: 6.77s
# 67:	learn: 0.0025406	total: 493ms	remaining: 6.75s
# 68:	learn: 0.0025285	total: 498ms	remaining: 6.72s
# 69:	learn: 0.0025079	total: 504ms	remaining: 6.7s
# 70:	learn: 0.0024978	total: 511ms	remaining: 6.68s
# 71:	learn: 0.0024960	total: 516ms	remaining: 6.65s
# 72:	learn: 0.0024865	total: 522ms	remaining: 6.63s
# 73:	learn: 0.0024657	total: 528ms	remaining: 6.61s
# 74:	learn: 0.0024622	total: 534ms	remaining: 6.59s
# 75:	learn: 0.0024547	total: 541ms	remaining: 6.57s
# 76:	learn: 0.0024404	total: 547ms	remaining: 6.55s
# 77:	learn: 0.0024338	total: 552ms	remaining: 6.53s
# 78:	learn: 0.0024125	total: 558ms	remaining: 6.5s
# 79:	learn: 0.0024110	total: 564ms	remaining: 6.48s
# 80:	learn: 0.0024000	total: 570ms	remaining: 6.47s
# 81:	learn: 0.0023817	total: 576ms	remaining: 6.45s
# 82:	learn: 0.0023714	total: 583ms	remaining: 6.45s
# 83:	learn: 0.0023699	total: 589ms	remaining: 6.43s
# 84:	learn: 0.0023502	total: 596ms	remaining: 6.41s
# 85:	learn: 0.0023364	total: 602ms	remaining: 6.4s
# 86:	learn: 0.0023258	total: 609ms	remaining: 6.39s
# 87:	learn: 0.0023101	total: 615ms	remaining: 6.37s
# 88:	learn: 0.0022977	total: 621ms	remaining: 6.35s
# 89:	learn: 0.0022853	total: 627ms	remaining: 6.33s
# 90:	learn: 0.0022735	total: 633ms	remaining: 6.32s
# 91:	learn: 0.0022653	total: 639ms	remaining: 6.3s
# 92:	learn: 0.0022554	total: 644ms	remaining: 6.28s
# 93:	learn: 0.0022416	total: 650ms	remaining: 6.27s
# 94:	learn: 0.0022333	total: 657ms	remaining: 6.25s
# 95:	learn: 0.0022106	total: 663ms	remaining: 6.24s
# 96:	learn: 0.0022034	total: 669ms	remaining: 6.23s
# 97:	learn: 0.0021906	total: 675ms	remaining: 6.21s
# 98:	learn: 0.0021810	total: 681ms	remaining: 6.2s
# 99:	learn: 0.0021795	total: 687ms	remaining: 6.19s
# 100:	learn: 0.0021657	total: 693ms	remaining: 6.17s
# 101:	learn: 0.0021643	total: 699ms	remaining: 6.15s
# 102:	learn: 0.0021461	total: 705ms	remaining: 6.14s
# 103:	learn: 0.0021347	total: 711ms	remaining: 6.13s
# 104:	learn: 0.0021333	total: 717ms	remaining: 6.11s
# 105:	learn: 0.0021319	total: 723ms	remaining: 6.1s
# 106:	learn: 0.0021306	total: 730ms	remaining: 6.09s
# 107:	learn: 0.0021293	total: 736ms	remaining: 6.08s
# 108:	learn: 0.0021242	total: 743ms	remaining: 6.07s
# 109:	learn: 0.0021049	total: 749ms	remaining: 6.06s
# 110:	learn: 0.0021037	total: 754ms	remaining: 6.04s
# 111:	learn: 0.0020926	total: 760ms	remaining: 6.03s
# 112:	learn: 0.0020853	total: 766ms	remaining: 6.01s
# 113:	learn: 0.0020681	total: 771ms	remaining: 6s
# 114:	learn: 0.0020625	total: 777ms	remaining: 5.98s
# 115:	learn: 0.0020377	total: 784ms	remaining: 5.97s
# 116:	learn: 0.0020169	total: 790ms	remaining: 5.96s
# 117:	learn: 0.0019939	total: 797ms	remaining: 5.96s
# 118:	learn: 0.0019927	total: 803ms	remaining: 5.94s
# 119:	learn: 0.0019916	total: 809ms	remaining: 5.93s
# 120:	learn: 0.0019905	total: 815ms	remaining: 5.92s
# 121:	learn: 0.0019778	total: 821ms	remaining: 5.91s
# 122:	learn: 0.0019655	total: 827ms	remaining: 5.9s
# 123:	learn: 0.0019565	total: 833ms	remaining: 5.88s
# 124:	learn: 0.0019385	total: 840ms	remaining: 5.88s
# 125:	learn: 0.0019181	total: 846ms	remaining: 5.87s
# 126:	learn: 0.0019119	total: 853ms	remaining: 5.86s
# 127:	learn: 0.0019108	total: 861ms	remaining: 5.86s
# 128:	learn: 0.0019097	total: 867ms	remaining: 5.85s
# 129:	learn: 0.0019085	total: 873ms	remaining: 5.84s
# 130:	learn: 0.0018989	total: 878ms	remaining: 5.83s
# 131:	learn: 0.0018976	total: 884ms	remaining: 5.82s
# 132:	learn: 0.0018964	total: 891ms	remaining: 5.8s
# 133:	learn: 0.0018894	total: 896ms	remaining: 5.79s
# 134:	learn: 0.0018813	total: 903ms	remaining: 5.78s
# 135:	learn: 0.0018801	total: 908ms	remaining: 5.77s
# 136:	learn: 0.0018790	total: 914ms	remaining: 5.76s
# 137:	learn: 0.0018739	total: 921ms	remaining: 5.75s
# 138:	learn: 0.0018691	total: 927ms	remaining: 5.74s
# 139:	learn: 0.0018574	total: 933ms	remaining: 5.73s
# 140:	learn: 0.0018479	total: 939ms	remaining: 5.72s
# 141:	learn: 0.0018426	total: 945ms	remaining: 5.71s
# 142:	learn: 0.0018347	total: 951ms	remaining: 5.7s
# 143:	learn: 0.0018292	total: 958ms	remaining: 5.69s
# 144:	learn: 0.0018219	total: 963ms	remaining: 5.68s
# 145:	learn: 0.0018154	total: 970ms	remaining: 5.67s
# 146:	learn: 0.0017994	total: 976ms	remaining: 5.66s
# 147:	learn: 0.0017983	total: 981ms	remaining: 5.65s
# 148:	learn: 0.0017869	total: 987ms	remaining: 5.64s
# 149:	learn: 0.0017858	total: 994ms	remaining: 5.63s
# 150:	learn: 0.0017705	total: 1000ms	remaining: 5.62s
# 151:	learn: 0.0017694	total: 1s	remaining: 5.61s
# 152:	learn: 0.0017684	total: 1.01s	remaining: 5.6s
# 153:	learn: 0.0017605	total: 1.02s	remaining: 5.59s
# 154:	learn: 0.0017595	total: 1.02s	remaining: 5.58s
# 155:	learn: 0.0017585	total: 1.03s	remaining: 5.57s
# 156:	learn: 0.0017455	total: 1.03s	remaining: 5.56s
# 157:	learn: 0.0017445	total: 1.04s	remaining: 5.55s
# 158:	learn: 0.0017435	total: 1.05s	remaining: 5.54s
# 159:	learn: 0.0017426	total: 1.05s	remaining: 5.53s
# 160:	learn: 0.0017371	total: 1.06s	remaining: 5.52s
# 161:	learn: 0.0017363	total: 1.07s	remaining: 5.51s
# 162:	learn: 0.0017302	total: 1.07s	remaining: 5.5s
# 163:	learn: 0.0017188	total: 1.08s	remaining: 5.5s
# 164:	learn: 0.0017102	total: 1.08s	remaining: 5.49s
# 165:	learn: 0.0016952	total: 1.09s	remaining: 5.48s
# 166:	learn: 0.0016889	total: 1.1s	remaining: 5.47s
# 167:	learn: 0.0016844	total: 1.1s	remaining: 5.46s
# 168:	learn: 0.0016806	total: 1.11s	remaining: 5.46s
# 169:	learn: 0.0016737	total: 1.11s	remaining: 5.45s
# 170:	learn: 0.0016634	total: 1.12s	remaining: 5.44s
# 171:	learn: 0.0016626	total: 1.13s	remaining: 5.43s
# 172:	learn: 0.0016618	total: 1.13s	remaining: 5.42s
# 173:	learn: 0.0016568	total: 1.14s	remaining: 5.41s
# 174:	learn: 0.0016558	total: 1.15s	remaining: 5.4s
# 175:	learn: 0.0016481	total: 1.15s	remaining: 5.4s
# 176:	learn: 0.0016473	total: 1.16s	remaining: 5.39s
# 177:	learn: 0.0016465	total: 1.16s	remaining: 5.38s
# 178:	learn: 0.0016419	total: 1.17s	remaining: 5.37s
# 179:	learn: 0.0016361	total: 1.18s	remaining: 5.36s
# 180:	learn: 0.0016281	total: 1.18s	remaining: 5.35s
# 181:	learn: 0.0016214	total: 1.19s	remaining: 5.35s
# 182:	learn: 0.0016166	total: 1.2s	remaining: 5.34s
# 183:	learn: 0.0016094	total: 1.2s	remaining: 5.33s
# 184:	learn: 0.0016058	total: 1.21s	remaining: 5.32s
# 185:	learn: 0.0016001	total: 1.22s	remaining: 5.32s
# 186:	learn: 0.0015936	total: 1.22s	remaining: 5.31s
# 187:	learn: 0.0015813	total: 1.23s	remaining: 5.3s
# 188:	learn: 0.0015722	total: 1.23s	remaining: 5.29s
# 189:	learn: 0.0015621	total: 1.24s	remaining: 5.29s
# 190:	learn: 0.0015575	total: 1.25s	remaining: 5.28s
# 191:	learn: 0.0015566	total: 1.25s	remaining: 5.27s
# 192:	learn: 0.0015529	total: 1.26s	remaining: 5.26s
# 193:	learn: 0.0015511	total: 1.26s	remaining: 5.25s
# 194:	learn: 0.0015452	total: 1.27s	remaining: 5.25s
# 195:	learn: 0.0015399	total: 1.28s	remaining: 5.24s
# 196:	learn: 0.0015323	total: 1.28s	remaining: 5.23s
# 197:	learn: 0.0015209	total: 1.29s	remaining: 5.22s
# 198:	learn: 0.0015145	total: 1.29s	remaining: 5.21s
# 199:	learn: 0.0015138	total: 1.3s	remaining: 5.21s
# 200:	learn: 0.0015129	total: 1.31s	remaining: 5.2s
# 201:	learn: 0.0015061	total: 1.31s	remaining: 5.19s
# 202:	learn: 0.0015018	total: 1.32s	remaining: 5.18s
# 203:	learn: 0.0014918	total: 1.33s	remaining: 5.17s
# 204:	learn: 0.0014757	total: 1.33s	remaining: 5.17s
# 205:	learn: 0.0014750	total: 1.34s	remaining: 5.16s
# 206:	learn: 0.0014668	total: 1.35s	remaining: 5.16s
# 207:	learn: 0.0014662	total: 1.35s	remaining: 5.15s
# 208:	learn: 0.0014645	total: 1.36s	remaining: 5.14s
# 209:	learn: 0.0014638	total: 1.36s	remaining: 5.13s
# 210:	learn: 0.0014566	total: 1.37s	remaining: 5.13s
# 211:	learn: 0.0014558	total: 1.38s	remaining: 5.12s
# 212:	learn: 0.0014419	total: 1.4s	remaining: 5.19s
# 213:	learn: 0.0014384	total: 1.43s	remaining: 5.24s
# 214:	learn: 0.0014340	total: 1.44s	remaining: 5.25s
# 215:	learn: 0.0014289	total: 1.46s	remaining: 5.29s
# 216:	learn: 0.0014269	total: 1.46s	remaining: 5.29s
# 217:	learn: 0.0014262	total: 1.49s	remaining: 5.33s
# 218:	learn: 0.0014227	total: 1.49s	remaining: 5.33s
# 219:	learn: 0.0014188	total: 1.51s	remaining: 5.34s
# 220:	learn: 0.0014117	total: 1.51s	remaining: 5.33s
# 221:	learn: 0.0014025	total: 1.52s	remaining: 5.32s
# 222:	learn: 0.0013956	total: 1.52s	remaining: 5.31s
# 223:	learn: 0.0013855	total: 1.53s	remaining: 5.3s
# 224:	learn: 0.0013762	total: 1.54s	remaining: 5.29s
# 225:	learn: 0.0013719	total: 1.54s	remaining: 5.29s
# 226:	learn: 0.0013683	total: 1.55s	remaining: 5.28s
# 227:	learn: 0.0013600	total: 1.55s	remaining: 5.27s
# 228:	learn: 0.0013547	total: 1.56s	remaining: 5.26s
# 229:	learn: 0.0013479	total: 1.57s	remaining: 5.25s
# 230:	learn: 0.0013440	total: 1.57s	remaining: 5.24s
# 231:	learn: 0.0013398	total: 1.58s	remaining: 5.23s
# 232:	learn: 0.0013362	total: 1.58s	remaining: 5.22s
# 233:	learn: 0.0013310	total: 1.59s	remaining: 5.21s
# 234:	learn: 0.0013257	total: 1.6s	remaining: 5.2s
# 235:	learn: 0.0013201	total: 1.6s	remaining: 5.19s
# 236:	learn: 0.0013168	total: 1.61s	remaining: 5.18s
# 237:	learn: 0.0013141	total: 1.61s	remaining: 5.17s
# 238:	learn: 0.0013067	total: 1.62s	remaining: 5.16s
# 239:	learn: 0.0012967	total: 1.63s	remaining: 5.15s
# 240:	learn: 0.0012923	total: 1.63s	remaining: 5.14s
# 241:	learn: 0.0012845	total: 1.64s	remaining: 5.14s
# 242:	learn: 0.0012763	total: 1.65s	remaining: 5.13s
# 243:	learn: 0.0012731	total: 1.65s	remaining: 5.12s
# 244:	learn: 0.0012689	total: 1.66s	remaining: 5.11s
# 245:	learn: 0.0012623	total: 1.66s	remaining: 5.1s
# 246:	learn: 0.0012557	total: 1.67s	remaining: 5.09s
# 247:	learn: 0.0012495	total: 1.68s	remaining: 5.08s
# 248:	learn: 0.0012490	total: 1.68s	remaining: 5.07s
# 249:	learn: 0.0012387	total: 1.69s	remaining: 5.06s
# 250:	learn: 0.0012342	total: 1.69s	remaining: 5.06s
# 251:	learn: 0.0012289	total: 1.7s	remaining: 5.05s
# 252:	learn: 0.0012230	total: 1.71s	remaining: 5.04s
# 253:	learn: 0.0012179	total: 1.71s	remaining: 5.03s
# 254:	learn: 0.0012094	total: 1.72s	remaining: 5.03s
# 255:	learn: 0.0012088	total: 1.73s	remaining: 5.02s
# 256:	learn: 0.0012011	total: 1.73s	remaining: 5.01s
# 257:	learn: 0.0011965	total: 1.74s	remaining: 5s
# 258:	learn: 0.0011901	total: 1.75s	remaining: 4.99s
# 259:	learn: 0.0011895	total: 1.75s	remaining: 4.98s
# 260:	learn: 0.0011845	total: 1.76s	remaining: 4.97s
# 261:	learn: 0.0011839	total: 1.76s	remaining: 4.97s
# 262:	learn: 0.0011780	total: 1.77s	remaining: 4.96s
# 263:	learn: 0.0011691	total: 1.77s	remaining: 4.95s
# 264:	learn: 0.0011667	total: 1.78s	remaining: 4.94s
# 265:	learn: 0.0011647	total: 1.79s	remaining: 4.93s
# 266:	learn: 0.0011588	total: 1.79s	remaining: 4.92s
# 267:	learn: 0.0011582	total: 1.8s	remaining: 4.92s
# 268:	learn: 0.0011577	total: 1.8s	remaining: 4.91s
# 269:	learn: 0.0011535	total: 1.81s	remaining: 4.9s
# 270:	learn: 0.0011473	total: 1.82s	remaining: 4.89s
# 271:	learn: 0.0011468	total: 1.82s	remaining: 4.88s
# 272:	learn: 0.0011463	total: 1.83s	remaining: 4.87s
# 273:	learn: 0.0011386	total: 1.84s	remaining: 4.87s
# 274:	learn: 0.0011344	total: 1.84s	remaining: 4.86s
# 275:	learn: 0.0011263	total: 1.85s	remaining: 4.85s
# 276:	learn: 0.0011258	total: 1.85s	remaining: 4.84s
# 277:	learn: 0.0011204	total: 1.86s	remaining: 4.83s
# 278:	learn: 0.0011200	total: 1.87s	remaining: 4.83s
# 279:	learn: 0.0011148	total: 1.87s	remaining: 4.82s
# 280:	learn: 0.0011133	total: 1.88s	remaining: 4.81s
# 281:	learn: 0.0011046	total: 1.89s	remaining: 4.8s
# 282:	learn: 0.0011039	total: 1.89s	remaining: 4.79s
# 283:	learn: 0.0010934	total: 1.9s	remaining: 4.79s
# 284:	learn: 0.0010882	total: 1.9s	remaining: 4.78s
# 285:	learn: 0.0010877	total: 1.91s	remaining: 4.77s
# 286:	learn: 0.0010776	total: 1.92s	remaining: 4.76s
# 287:	learn: 0.0010772	total: 1.92s	remaining: 4.75s
# 288:	learn: 0.0010757	total: 1.93s	remaining: 4.74s
# 289:	learn: 0.0010753	total: 1.93s	remaining: 4.74s
# 290:	learn: 0.0010749	total: 1.94s	remaining: 4.72s
# 291:	learn: 0.0010744	total: 1.95s	remaining: 4.72s
# 292:	learn: 0.0010740	total: 1.95s	remaining: 4.71s
# 293:	learn: 0.0010653	total: 1.96s	remaining: 4.7s
# 294:	learn: 0.0010605	total: 1.96s	remaining: 4.69s
# 295:	learn: 0.0010522	total: 1.97s	remaining: 4.68s
# 296:	learn: 0.0010518	total: 1.98s	remaining: 4.68s
# 297:	learn: 0.0010453	total: 1.98s	remaining: 4.67s
# 298:	learn: 0.0010390	total: 1.99s	remaining: 4.66s
# 299:	learn: 0.0010365	total: 1.99s	remaining: 4.65s
# 300:	learn: 0.0010305	total: 2s	remaining: 4.64s
# 301:	learn: 0.0010262	total: 2.01s	remaining: 4.64s
# 302:	learn: 0.0010218	total: 2.01s	remaining: 4.63s
# 303:	learn: 0.0010184	total: 2.02s	remaining: 4.62s
# 304:	learn: 0.0010146	total: 2.02s	remaining: 4.61s
# 305:	learn: 0.0010110	total: 2.03s	remaining: 4.6s
# 306:	learn: 0.0010017	total: 2.04s	remaining: 4.59s
# 307:	learn: 0.0009955	total: 2.04s	remaining: 4.59s
# 308:	learn: 0.0009904	total: 2.05s	remaining: 4.58s
# 309:	learn: 0.0009839	total: 2.05s	remaining: 4.57s
# 310:	learn: 0.0009810	total: 2.06s	remaining: 4.57s
# 311:	learn: 0.0009726	total: 2.07s	remaining: 4.56s
# 312:	learn: 0.0009699	total: 2.07s	remaining: 4.55s
# 313:	learn: 0.0009665	total: 2.08s	remaining: 4.54s
# 314:	learn: 0.0009625	total: 2.08s	remaining: 4.53s
# 315:	learn: 0.0009586	total: 2.09s	remaining: 4.53s
# 316:	learn: 0.0009516	total: 2.1s	remaining: 4.52s
# 317:	learn: 0.0009499	total: 2.1s	remaining: 4.51s
# 318:	learn: 0.0009469	total: 2.11s	remaining: 4.5s
# 319:	learn: 0.0009462	total: 2.12s	remaining: 4.5s
# 320:	learn: 0.0009407	total: 2.12s	remaining: 4.49s
# 321:	learn: 0.0009381	total: 2.13s	remaining: 4.48s
# 322:	learn: 0.0009349	total: 2.13s	remaining: 4.47s
# 323:	learn: 0.0009307	total: 2.14s	remaining: 4.47s
# 324:	learn: 0.0009258	total: 2.15s	remaining: 4.46s
# 325:	learn: 0.0009220	total: 2.15s	remaining: 4.45s
# 326:	learn: 0.0009173	total: 2.16s	remaining: 4.45s
# 327:	learn: 0.0009130	total: 2.17s	remaining: 4.44s
# 328:	learn: 0.0009126	total: 2.17s	remaining: 4.43s
# 329:	learn: 0.0009064	total: 2.18s	remaining: 4.42s
# 330:	learn: 0.0009010	total: 2.18s	remaining: 4.41s
# 331:	learn: 0.0008993	total: 2.19s	remaining: 4.41s
# 332:	learn: 0.0008962	total: 2.19s	remaining: 4.4s
# 333:	learn: 0.0008937	total: 2.2s	remaining: 4.39s
# 334:	learn: 0.0008932	total: 2.21s	remaining: 4.38s
# 335:	learn: 0.0008929	total: 2.21s	remaining: 4.38s
# 336:	learn: 0.0008924	total: 2.22s	remaining: 4.37s
# 337:	learn: 0.0008868	total: 2.23s	remaining: 4.36s
# 338:	learn: 0.0008865	total: 2.23s	remaining: 4.35s
# 339:	learn: 0.0008825	total: 2.24s	remaining: 4.35s
# 340:	learn: 0.0008769	total: 2.25s	remaining: 4.34s
# 341:	learn: 0.0008730	total: 2.25s	remaining: 4.33s
# 342:	learn: 0.0008693	total: 2.26s	remaining: 4.32s
# 343:	learn: 0.0008633	total: 2.26s	remaining: 4.32s
# 344:	learn: 0.0008629	total: 2.27s	remaining: 4.31s
# 345:	learn: 0.0008612	total: 2.28s	remaining: 4.3s
# 346:	learn: 0.0008574	total: 2.28s	remaining: 4.29s
# 347:	learn: 0.0008566	total: 2.29s	remaining: 4.29s
# 348:	learn: 0.0008496	total: 2.29s	remaining: 4.28s
# 349:	learn: 0.0008452	total: 2.3s	remaining: 4.27s
# 350:	learn: 0.0008449	total: 2.31s	remaining: 4.26s
# 351:	learn: 0.0008433	total: 2.31s	remaining: 4.26s
# 352:	learn: 0.0008410	total: 2.32s	remaining: 4.25s
# 353:	learn: 0.0008376	total: 2.32s	remaining: 4.24s
# 354:	learn: 0.0008324	total: 2.33s	remaining: 4.23s
# 355:	learn: 0.0008296	total: 2.34s	remaining: 4.23s
# 356:	learn: 0.0008282	total: 2.34s	remaining: 4.22s
# 357:	learn: 0.0008275	total: 2.35s	remaining: 4.21s
# 358:	learn: 0.0008221	total: 2.35s	remaining: 4.2s
# 359:	learn: 0.0008203	total: 2.36s	remaining: 4.2s
# 360:	learn: 0.0008199	total: 2.37s	remaining: 4.19s
# 361:	learn: 0.0008197	total: 2.37s	remaining: 4.18s
# 362:	learn: 0.0008194	total: 2.38s	remaining: 4.17s
# 363:	learn: 0.0008191	total: 2.38s	remaining: 4.17s
# 364:	learn: 0.0008178	total: 2.39s	remaining: 4.16s
# 365:	learn: 0.0008152	total: 2.4s	remaining: 4.15s
# 366:	learn: 0.0008120	total: 2.4s	remaining: 4.14s
# 367:	learn: 0.0008039	total: 2.41s	remaining: 4.14s
# 368:	learn: 0.0007981	total: 2.42s	remaining: 4.13s
# 369:	learn: 0.0007960	total: 2.42s	remaining: 4.13s
# 370:	learn: 0.0007950	total: 2.43s	remaining: 4.12s
# 371:	learn: 0.0007926	total: 2.43s	remaining: 4.11s
# 372:	learn: 0.0007869	total: 2.44s	remaining: 4.1s
# 373:	learn: 0.0007854	total: 2.45s	remaining: 4.1s
# 374:	learn: 0.0007821	total: 2.45s	remaining: 4.09s
# 375:	learn: 0.0007782	total: 2.46s	remaining: 4.08s
# 376:	learn: 0.0007777	total: 2.46s	remaining: 4.07s
# 377:	learn: 0.0007743	total: 2.47s	remaining: 4.06s
# 378:	learn: 0.0007665	total: 2.48s	remaining: 4.06s
# 379:	learn: 0.0007635	total: 2.48s	remaining: 4.05s
# 380:	learn: 0.0007614	total: 2.49s	remaining: 4.04s
# 381:	learn: 0.0007609	total: 2.49s	remaining: 4.03s
# 382:	learn: 0.0007605	total: 2.5s	remaining: 4.03s
# 383:	learn: 0.0007559	total: 2.51s	remaining: 4.02s
# 384:	learn: 0.0007520	total: 2.51s	remaining: 4.01s
# 385:	learn: 0.0007496	total: 2.52s	remaining: 4.01s
# 386:	learn: 0.0007424	total: 2.52s	remaining: 4s
# 387:	learn: 0.0007420	total: 2.53s	remaining: 3.99s
# 388:	learn: 0.0007389	total: 2.54s	remaining: 3.98s
# 389:	learn: 0.0007386	total: 2.54s	remaining: 3.98s
# 390:	learn: 0.0007383	total: 2.55s	remaining: 3.97s
# 391:	learn: 0.0007335	total: 2.56s	remaining: 3.96s
# 392:	learn: 0.0007332	total: 2.56s	remaining: 3.96s
# 393:	learn: 0.0007329	total: 2.57s	remaining: 3.95s
# 394:	learn: 0.0007326	total: 2.57s	remaining: 3.94s
# 395:	learn: 0.0007284	total: 2.58s	remaining: 3.94s
# 396:	learn: 0.0007244	total: 2.58s	remaining: 3.93s
# 397:	learn: 0.0007242	total: 2.59s	remaining: 3.92s
# 398:	learn: 0.0007239	total: 2.6s	remaining: 3.91s
# 399:	learn: 0.0007190	total: 2.6s	remaining: 3.9s
# 400:	learn: 0.0007185	total: 2.61s	remaining: 3.9s
# 401:	learn: 0.0007128	total: 2.62s	remaining: 3.89s
# 402:	learn: 0.0007116	total: 2.62s	remaining: 3.88s
# 403:	learn: 0.0007087	total: 2.63s	remaining: 3.88s
# 404:	learn: 0.0007035	total: 2.63s	remaining: 3.87s
# 405:	learn: 0.0007001	total: 2.64s	remaining: 3.86s
# 406:	learn: 0.0006966	total: 2.65s	remaining: 3.85s
# 407:	learn: 0.0006933	total: 2.65s	remaining: 3.85s
# 408:	learn: 0.0006912	total: 2.66s	remaining: 3.84s
# 409:	learn: 0.0006868	total: 2.66s	remaining: 3.83s
# 410:	learn: 0.0006854	total: 2.67s	remaining: 3.83s
# 411:	learn: 0.0006844	total: 2.68s	remaining: 3.82s
# 412:	learn: 0.0006816	total: 2.68s	remaining: 3.81s
# 413:	learn: 0.0006809	total: 2.69s	remaining: 3.8s
# 414:	learn: 0.0006802	total: 2.69s	remaining: 3.8s
# 415:	learn: 0.0006770	total: 2.7s	remaining: 3.79s
# 416:	learn: 0.0006763	total: 2.71s	remaining: 3.78s
# 417:	learn: 0.0006727	total: 2.71s	remaining: 3.78s
# 418:	learn: 0.0006693	total: 2.72s	remaining: 3.77s
# 419:	learn: 0.0006672	total: 2.73s	remaining: 3.76s
# 420:	learn: 0.0006626	total: 2.73s	remaining: 3.75s
# 421:	learn: 0.0006605	total: 2.74s	remaining: 3.75s
# 422:	learn: 0.0006597	total: 2.74s	remaining: 3.74s
# 423:	learn: 0.0006594	total: 2.75s	remaining: 3.73s
# 424:	learn: 0.0006587	total: 2.75s	remaining: 3.73s
# 425:	learn: 0.0006584	total: 2.76s	remaining: 3.72s
# 426:	learn: 0.0006582	total: 2.77s	remaining: 3.71s
# 427:	learn: 0.0006544	total: 2.77s	remaining: 3.71s
# 428:	learn: 0.0006525	total: 2.78s	remaining: 3.7s
# 429:	learn: 0.0006522	total: 2.78s	remaining: 3.69s
# 430:	learn: 0.0006520	total: 2.79s	remaining: 3.68s
# 431:	learn: 0.0006483	total: 2.79s	remaining: 3.67s
# 432:	learn: 0.0006454	total: 2.8s	remaining: 3.67s
# 433:	learn: 0.0006452	total: 2.81s	remaining: 3.66s
# 434:	learn: 0.0006426	total: 2.81s	remaining: 3.66s
# 435:	learn: 0.0006420	total: 2.82s	remaining: 3.65s
# 436:	learn: 0.0006418	total: 2.83s	remaining: 3.64s
# 437:	learn: 0.0006381	total: 2.83s	remaining: 3.63s
# 438:	learn: 0.0006360	total: 2.84s	remaining: 3.63s
# 439:	learn: 0.0006349	total: 2.85s	remaining: 3.62s
# 440:	learn: 0.0006330	total: 2.85s	remaining: 3.61s
# 441:	learn: 0.0006324	total: 2.86s	remaining: 3.61s
# 442:	learn: 0.0006310	total: 2.86s	remaining: 3.6s
# 443:	learn: 0.0006308	total: 2.87s	remaining: 3.59s
# 444:	learn: 0.0006266	total: 2.88s	remaining: 3.58s
# 445:	learn: 0.0006256	total: 2.88s	remaining: 3.58s
# 446:	learn: 0.0006242	total: 2.89s	remaining: 3.57s
# 447:	learn: 0.0006228	total: 2.89s	remaining: 3.56s
# 448:	learn: 0.0006210	total: 2.9s	remaining: 3.56s
# 449:	learn: 0.0006176	total: 2.91s	remaining: 3.55s
# 450:	learn: 0.0006161	total: 2.91s	remaining: 3.54s
# 451:	learn: 0.0006136	total: 2.92s	remaining: 3.54s
# 452:	learn: 0.0006127	total: 2.92s	remaining: 3.53s
# 453:	learn: 0.0006060	total: 2.93s	remaining: 3.52s
# 454:	learn: 0.0006044	total: 2.94s	remaining: 3.52s
# 455:	learn: 0.0006042	total: 2.94s	remaining: 3.51s
# 456:	learn: 0.0005986	total: 2.95s	remaining: 3.5s
# 457:	learn: 0.0005982	total: 2.96s	remaining: 3.5s
# 458:	learn: 0.0005933	total: 2.96s	remaining: 3.49s
# 459:	learn: 0.0005931	total: 2.97s	remaining: 3.48s
# 460:	learn: 0.0005927	total: 2.97s	remaining: 3.48s
# 461:	learn: 0.0005924	total: 2.98s	remaining: 3.47s
# 462:	learn: 0.0005922	total: 2.98s	remaining: 3.46s
# 463:	learn: 0.0005907	total: 2.99s	remaining: 3.45s
# 464:	learn: 0.0005887	total: 3s	remaining: 3.45s
# 465:	learn: 0.0005879	total: 3s	remaining: 3.44s
# 466:	learn: 0.0005859	total: 3.01s	remaining: 3.43s
# 467:	learn: 0.0005852	total: 3.01s	remaining: 3.43s
# 468:	learn: 0.0005850	total: 3.02s	remaining: 3.42s
# 469:	learn: 0.0005847	total: 3.03s	remaining: 3.41s
# 470:	learn: 0.0005824	total: 3.03s	remaining: 3.4s
# 471:	learn: 0.0005820	total: 3.04s	remaining: 3.4s
# 472:	learn: 0.0005819	total: 3.04s	remaining: 3.39s
# 473:	learn: 0.0005806	total: 3.05s	remaining: 3.38s
# 474:	learn: 0.0005783	total: 3.06s	remaining: 3.38s
# 475:	learn: 0.0005773	total: 3.06s	remaining: 3.37s
# 476:	learn: 0.0005757	total: 3.07s	remaining: 3.36s
# 477:	learn: 0.0005735	total: 3.07s	remaining: 3.36s
# 478:	learn: 0.0005708	total: 3.08s	remaining: 3.35s
# 479:	learn: 0.0005667	total: 3.09s	remaining: 3.34s
# 480:	learn: 0.0005665	total: 3.09s	remaining: 3.34s
# 481:	learn: 0.0005647	total: 3.1s	remaining: 3.33s
# 482:	learn: 0.0005631	total: 3.1s	remaining: 3.32s
# 483:	learn: 0.0005587	total: 3.11s	remaining: 3.32s
# 484:	learn: 0.0005552	total: 3.12s	remaining: 3.31s
# 485:	learn: 0.0005527	total: 3.12s	remaining: 3.3s
# 486:	learn: 0.0005525	total: 3.13s	remaining: 3.29s
# 487:	learn: 0.0005518	total: 3.13s	remaining: 3.29s
# 488:	learn: 0.0005507	total: 3.14s	remaining: 3.28s
# 489:	learn: 0.0005477	total: 3.15s	remaining: 3.27s
# 490:	learn: 0.0005471	total: 3.15s	remaining: 3.27s
# 491:	learn: 0.0005469	total: 3.16s	remaining: 3.26s
# 492:	learn: 0.0005447	total: 3.17s	remaining: 3.26s
# 493:	learn: 0.0005444	total: 3.17s	remaining: 3.25s
# 494:	learn: 0.0005432	total: 3.18s	remaining: 3.24s
# 495:	learn: 0.0005394	total: 3.18s	remaining: 3.24s
# 496:	learn: 0.0005373	total: 3.19s	remaining: 3.23s
# 497:	learn: 0.0005365	total: 3.2s	remaining: 3.22s
# 498:	learn: 0.0005363	total: 3.2s	remaining: 3.22s
# 499:	learn: 0.0005359	total: 3.21s	remaining: 3.21s
# 500:	learn: 0.0005349	total: 3.21s	remaining: 3.2s
# 501:	learn: 0.0005347	total: 3.22s	remaining: 3.2s
# 502:	learn: 0.0005309	total: 3.23s	remaining: 3.19s
# 503:	learn: 0.0005286	total: 3.23s	remaining: 3.18s
# 504:	learn: 0.0005258	total: 3.24s	remaining: 3.17s
# 505:	learn: 0.0005230	total: 3.25s	remaining: 3.17s
# 506:	learn: 0.0005211	total: 3.25s	remaining: 3.16s
# 507:	learn: 0.0005197	total: 3.26s	remaining: 3.15s
# 508:	learn: 0.0005167	total: 3.26s	remaining: 3.15s
# 509:	learn: 0.0005165	total: 3.27s	remaining: 3.14s
# 510:	learn: 0.0005162	total: 3.28s	remaining: 3.13s
# 511:	learn: 0.0005161	total: 3.28s	remaining: 3.13s
# 512:	learn: 0.0005125	total: 3.29s	remaining: 3.12s
# 513:	learn: 0.0005094	total: 3.29s	remaining: 3.12s
# 514:	learn: 0.0005069	total: 3.3s	remaining: 3.11s
# 515:	learn: 0.0005028	total: 3.31s	remaining: 3.1s
# 516:	learn: 0.0004995	total: 3.31s	remaining: 3.1s
# 517:	learn: 0.0004992	total: 3.32s	remaining: 3.09s
# 518:	learn: 0.0004978	total: 3.33s	remaining: 3.08s
# 519:	learn: 0.0004972	total: 3.33s	remaining: 3.08s
# 520:	learn: 0.0004969	total: 3.34s	remaining: 3.07s
# 521:	learn: 0.0004941	total: 3.34s	remaining: 3.06s
# 522:	learn: 0.0004924	total: 3.35s	remaining: 3.06s
# 523:	learn: 0.0004913	total: 3.36s	remaining: 3.05s
# 524:	learn: 0.0004904	total: 3.36s	remaining: 3.04s
# 525:	learn: 0.0004862	total: 3.37s	remaining: 3.04s
# 526:	learn: 0.0004853	total: 3.37s	remaining: 3.03s
# 527:	learn: 0.0004842	total: 3.38s	remaining: 3.02s
# 528:	learn: 0.0004808	total: 3.39s	remaining: 3.02s
# 529:	learn: 0.0004781	total: 3.39s	remaining: 3.01s
# 530:	learn: 0.0004766	total: 3.4s	remaining: 3s
# 531:	learn: 0.0004765	total: 3.4s	remaining: 3s
# 532:	learn: 0.0004730	total: 3.41s	remaining: 2.99s
# 533:	learn: 0.0004725	total: 3.42s	remaining: 2.98s
# 534:	learn: 0.0004719	total: 3.42s	remaining: 2.98s
# 535:	learn: 0.0004677	total: 3.43s	remaining: 2.97s
# 536:	learn: 0.0004652	total: 3.44s	remaining: 2.96s
# 537:	learn: 0.0004630	total: 3.44s	remaining: 2.96s
# 538:	learn: 0.0004614	total: 3.45s	remaining: 2.95s
# 539:	learn: 0.0004585	total: 3.45s	remaining: 2.94s
# 540:	learn: 0.0004578	total: 3.46s	remaining: 2.94s
# 541:	learn: 0.0004545	total: 3.47s	remaining: 2.93s
# 542:	learn: 0.0004540	total: 3.47s	remaining: 2.92s
# 543:	learn: 0.0004535	total: 3.48s	remaining: 2.92s
# 544:	learn: 0.0004500	total: 3.48s	remaining: 2.91s
# 545:	learn: 0.0004482	total: 3.49s	remaining: 2.9s
# 546:	learn: 0.0004437	total: 3.5s	remaining: 2.9s
# 547:	learn: 0.0004436	total: 3.5s	remaining: 2.89s
# 548:	learn: 0.0004428	total: 3.51s	remaining: 2.88s
# 549:	learn: 0.0004403	total: 3.51s	remaining: 2.88s
# 550:	learn: 0.0004401	total: 3.52s	remaining: 2.87s
# 551:	learn: 0.0004377	total: 3.53s	remaining: 2.86s
# 552:	learn: 0.0004351	total: 3.53s	remaining: 2.86s
# 553:	learn: 0.0004348	total: 3.54s	remaining: 2.85s
# 554:	learn: 0.0004345	total: 3.54s	remaining: 2.84s
# 555:	learn: 0.0004318	total: 3.55s	remaining: 2.84s
# 556:	learn: 0.0004305	total: 3.56s	remaining: 2.83s
# 557:	learn: 0.0004300	total: 3.56s	remaining: 2.82s
# 558:	learn: 0.0004292	total: 3.57s	remaining: 2.82s
# 559:	learn: 0.0004250	total: 3.58s	remaining: 2.81s
# 560:	learn: 0.0004236	total: 3.58s	remaining: 2.8s
# 561:	learn: 0.0004234	total: 3.59s	remaining: 2.8s
# 562:	learn: 0.0004229	total: 3.59s	remaining: 2.79s
# 563:	learn: 0.0004227	total: 3.6s	remaining: 2.78s
# 564:	learn: 0.0004215	total: 3.61s	remaining: 2.78s
# 565:	learn: 0.0004207	total: 3.61s	remaining: 2.77s
# 566:	learn: 0.0004194	total: 3.62s	remaining: 2.76s
# 567:	learn: 0.0004192	total: 3.62s	remaining: 2.76s
# 568:	learn: 0.0004156	total: 3.63s	remaining: 2.75s
# 569:	learn: 0.0004132	total: 3.64s	remaining: 2.74s
# 570:	learn: 0.0004130	total: 3.64s	remaining: 2.74s
# 571:	learn: 0.0004112	total: 3.65s	remaining: 2.73s
# 572:	learn: 0.0004083	total: 3.65s	remaining: 2.72s
# 573:	learn: 0.0004072	total: 3.66s	remaining: 2.72s
# 574:	learn: 0.0004070	total: 3.67s	remaining: 2.71s
# 575:	learn: 0.0004069	total: 3.67s	remaining: 2.7s
# 576:	learn: 0.0004056	total: 3.68s	remaining: 2.7s
# 577:	learn: 0.0004030	total: 3.68s	remaining: 2.69s
# 578:	learn: 0.0003990	total: 3.69s	remaining: 2.68s
# 579:	learn: 0.0003963	total: 3.7s	remaining: 2.68s
# 580:	learn: 0.0003942	total: 3.7s	remaining: 2.67s
# 581:	learn: 0.0003940	total: 3.71s	remaining: 2.66s
# 582:	learn: 0.0003921	total: 3.71s	remaining: 2.66s
# 583:	learn: 0.0003906	total: 3.72s	remaining: 2.65s
# 584:	learn: 0.0003895	total: 3.73s	remaining: 2.64s
# 585:	learn: 0.0003888	total: 3.73s	remaining: 2.64s
# 586:	learn: 0.0003867	total: 3.74s	remaining: 2.63s
# 587:	learn: 0.0003844	total: 3.75s	remaining: 2.62s
# 588:	learn: 0.0003840	total: 3.75s	remaining: 2.62s
# 589:	learn: 0.0003838	total: 3.76s	remaining: 2.61s
# 590:	learn: 0.0003836	total: 3.76s	remaining: 2.6s
# 591:	learn: 0.0003834	total: 3.77s	remaining: 2.6s
# 592:	learn: 0.0003830	total: 3.78s	remaining: 2.59s
# 593:	learn: 0.0003807	total: 3.78s	remaining: 2.58s
# 594:	learn: 0.0003786	total: 3.79s	remaining: 2.58s
# 595:	learn: 0.0003768	total: 3.79s	remaining: 2.57s
# 596:	learn: 0.0003767	total: 3.8s	remaining: 2.56s
# 597:	learn: 0.0003748	total: 3.81s	remaining: 2.56s
# 598:	learn: 0.0003728	total: 3.81s	remaining: 2.55s
# 599:	learn: 0.0003727	total: 3.82s	remaining: 2.55s
# 600:	learn: 0.0003711	total: 3.83s	remaining: 2.54s
# 601:	learn: 0.0003677	total: 3.83s	remaining: 2.53s
# 602:	learn: 0.0003653	total: 3.84s	remaining: 2.53s
# 603:	learn: 0.0003639	total: 3.84s	remaining: 2.52s
# 604:	learn: 0.0003637	total: 3.85s	remaining: 2.51s
# 605:	learn: 0.0003635	total: 3.85s	remaining: 2.51s
# 606:	learn: 0.0003609	total: 3.86s	remaining: 2.5s
# 607:	learn: 0.0003597	total: 3.87s	remaining: 2.49s
# 608:	learn: 0.0003591	total: 3.87s	remaining: 2.49s
# 609:	learn: 0.0003578	total: 3.88s	remaining: 2.48s
# 610:	learn: 0.0003577	total: 3.89s	remaining: 2.47s
# 611:	learn: 0.0003562	total: 3.89s	remaining: 2.47s
# 612:	learn: 0.0003530	total: 3.9s	remaining: 2.46s
# 613:	learn: 0.0003512	total: 3.9s	remaining: 2.46s
# 614:	learn: 0.0003500	total: 3.91s	remaining: 2.45s
# 615:	learn: 0.0003498	total: 3.92s	remaining: 2.44s
# 616:	learn: 0.0003488	total: 3.92s	remaining: 2.44s
# 617:	learn: 0.0003471	total: 3.93s	remaining: 2.43s
# 618:	learn: 0.0003469	total: 3.94s	remaining: 2.42s
# 619:	learn: 0.0003467	total: 3.94s	remaining: 2.42s
# 620:	learn: 0.0003457	total: 3.95s	remaining: 2.41s
# 621:	learn: 0.0003443	total: 3.96s	remaining: 2.4s
# 622:	learn: 0.0003421	total: 3.96s	remaining: 2.4s
# 623:	learn: 0.0003419	total: 3.97s	remaining: 2.39s
# 624:	learn: 0.0003412	total: 3.97s	remaining: 2.38s
# 625:	learn: 0.0003398	total: 3.98s	remaining: 2.38s
# 626:	learn: 0.0003393	total: 3.99s	remaining: 2.37s
# 627:	learn: 0.0003379	total: 3.99s	remaining: 2.36s
# 628:	learn: 0.0003378	total: 4s	remaining: 2.36s
# 629:	learn: 0.0003373	total: 4s	remaining: 2.35s
# 630:	learn: 0.0003372	total: 4.01s	remaining: 2.35s
# 631:	learn: 0.0003371	total: 4.02s	remaining: 2.34s
# 632:	learn: 0.0003366	total: 4.02s	remaining: 2.33s
# 633:	learn: 0.0003337	total: 4.03s	remaining: 2.33s
# 634:	learn: 0.0003303	total: 4.03s	remaining: 2.32s
# 635:	learn: 0.0003290	total: 4.04s	remaining: 2.31s
# 636:	learn: 0.0003288	total: 4.05s	remaining: 2.31s
# 637:	learn: 0.0003288	total: 4.05s	remaining: 2.3s
# 638:	learn: 0.0003286	total: 4.06s	remaining: 2.29s
# 639:	learn: 0.0003260	total: 4.06s	remaining: 2.29s
# 640:	learn: 0.0003254	total: 4.07s	remaining: 2.28s
# 641:	learn: 0.0003251	total: 4.08s	remaining: 2.27s
# 642:	learn: 0.0003222	total: 4.08s	remaining: 2.27s
# 643:	learn: 0.0003205	total: 4.09s	remaining: 2.26s
# 644:	learn: 0.0003193	total: 4.1s	remaining: 2.25s
# 645:	learn: 0.0003171	total: 4.1s	remaining: 2.25s
# 646:	learn: 0.0003161	total: 4.11s	remaining: 2.24s
# 647:	learn: 0.0003147	total: 4.12s	remaining: 2.23s
# 648:	learn: 0.0003122	total: 4.12s	remaining: 2.23s
# 649:	learn: 0.0003121	total: 4.13s	remaining: 2.22s
# 650:	learn: 0.0003109	total: 4.13s	remaining: 2.22s
# 651:	learn: 0.0003095	total: 4.14s	remaining: 2.21s
# 652:	learn: 0.0003089	total: 4.15s	remaining: 2.2s
# 653:	learn: 0.0003077	total: 4.15s	remaining: 2.2s
# 654:	learn: 0.0003074	total: 4.16s	remaining: 2.19s
# 655:	learn: 0.0003066	total: 4.17s	remaining: 2.18s
# 656:	learn: 0.0003060	total: 4.17s	remaining: 2.18s
# 657:	learn: 0.0003059	total: 4.18s	remaining: 2.17s
# 658:	learn: 0.0003053	total: 4.18s	remaining: 2.16s
# 659:	learn: 0.0003042	total: 4.19s	remaining: 2.16s
# 660:	learn: 0.0003041	total: 4.19s	remaining: 2.15s
# 661:	learn: 0.0003032	total: 4.2s	remaining: 2.14s
# 662:	learn: 0.0003028	total: 4.21s	remaining: 2.14s
# 663:	learn: 0.0003012	total: 4.21s	remaining: 2.13s
# 664:	learn: 0.0003006	total: 4.22s	remaining: 2.13s
# 665:	learn: 0.0002995	total: 4.22s	remaining: 2.12s
# 666:	learn: 0.0002993	total: 4.23s	remaining: 2.11s
# 667:	learn: 0.0002992	total: 4.24s	remaining: 2.1s
# 668:	learn: 0.0002966	total: 4.24s	remaining: 2.1s
# 669:	learn: 0.0002955	total: 4.25s	remaining: 2.09s
# 670:	learn: 0.0002954	total: 4.25s	remaining: 2.08s
# 671:	learn: 0.0002952	total: 4.26s	remaining: 2.08s
# 672:	learn: 0.0002948	total: 4.26s	remaining: 2.07s
# 673:	learn: 0.0002932	total: 4.27s	remaining: 2.06s
# 674:	learn: 0.0002927	total: 4.28s	remaining: 2.06s
# 675:	learn: 0.0002915	total: 4.28s	remaining: 2.05s
# 676:	learn: 0.0002907	total: 4.29s	remaining: 2.05s
# 677:	learn: 0.0002903	total: 4.29s	remaining: 2.04s
# 678:	learn: 0.0002890	total: 4.3s	remaining: 2.03s
# 679:	learn: 0.0002881	total: 4.31s	remaining: 2.03s
# 680:	learn: 0.0002870	total: 4.31s	remaining: 2.02s
# 681:	learn: 0.0002862	total: 4.32s	remaining: 2.01s
# 682:	learn: 0.0002858	total: 4.33s	remaining: 2.01s
# 683:	learn: 0.0002842	total: 4.33s	remaining: 2s
# 684:	learn: 0.0002830	total: 4.34s	remaining: 2s
# 685:	learn: 0.0002820	total: 4.35s	remaining: 1.99s
# 686:	learn: 0.0002815	total: 4.35s	remaining: 1.98s
# 687:	learn: 0.0002814	total: 4.36s	remaining: 1.98s
# 688:	learn: 0.0002806	total: 4.37s	remaining: 1.97s
# 689:	learn: 0.0002797	total: 4.37s	remaining: 1.96s
# 690:	learn: 0.0002775	total: 4.38s	remaining: 1.96s
# 691:	learn: 0.0002774	total: 4.38s	remaining: 1.95s
# 692:	learn: 0.0002768	total: 4.39s	remaining: 1.95s
# 693:	learn: 0.0002767	total: 4.4s	remaining: 1.94s
# 694:	learn: 0.0002755	total: 4.41s	remaining: 1.93s
# 695:	learn: 0.0002748	total: 4.41s	remaining: 1.93s
# 696:	learn: 0.0002744	total: 4.42s	remaining: 1.92s
# 697:	learn: 0.0002733	total: 4.42s	remaining: 1.91s
# 698:	learn: 0.0002729	total: 4.43s	remaining: 1.91s
# 699:	learn: 0.0002715	total: 4.43s	remaining: 1.9s
# 700:	learn: 0.0002713	total: 4.44s	remaining: 1.89s
# 701:	learn: 0.0002712	total: 4.45s	remaining: 1.89s
# 702:	learn: 0.0002698	total: 4.45s	remaining: 1.88s
# 703:	learn: 0.0002690	total: 4.46s	remaining: 1.87s
# 704:	learn: 0.0002682	total: 4.46s	remaining: 1.87s
# 705:	learn: 0.0002677	total: 4.47s	remaining: 1.86s
# 706:	learn: 0.0002660	total: 4.48s	remaining: 1.85s
# 707:	learn: 0.0002651	total: 4.48s	remaining: 1.85s
# 708:	learn: 0.0002646	total: 4.49s	remaining: 1.84s
# 709:	learn: 0.0002635	total: 4.5s	remaining: 1.84s
# 710:	learn: 0.0002629	total: 4.5s	remaining: 1.83s
# 711:	learn: 0.0002606	total: 4.51s	remaining: 1.82s
# 712:	learn: 0.0002596	total: 4.51s	remaining: 1.82s
# 713:	learn: 0.0002594	total: 4.52s	remaining: 1.81s
# 714:	learn: 0.0002586	total: 4.53s	remaining: 1.8s
# 715:	learn: 0.0002571	total: 4.53s	remaining: 1.8s
# 716:	learn: 0.0002569	total: 4.54s	remaining: 1.79s
# 717:	learn: 0.0002554	total: 4.54s	remaining: 1.78s
# 718:	learn: 0.0002534	total: 4.55s	remaining: 1.78s
# 719:	learn: 0.0002513	total: 4.56s	remaining: 1.77s
# 720:	learn: 0.0002511	total: 4.56s	remaining: 1.76s
# 721:	learn: 0.0002498	total: 4.57s	remaining: 1.76s
# 722:	learn: 0.0002495	total: 4.58s	remaining: 1.75s
# 723:	learn: 0.0002486	total: 4.58s	remaining: 1.75s
# 724:	learn: 0.0002472	total: 4.59s	remaining: 1.74s
# 725:	learn: 0.0002464	total: 4.59s	remaining: 1.73s
# 726:	learn: 0.0002442	total: 4.6s	remaining: 1.73s
# 727:	learn: 0.0002441	total: 4.61s	remaining: 1.72s
# 728:	learn: 0.0002433	total: 4.61s	remaining: 1.71s
# 729:	learn: 0.0002423	total: 4.62s	remaining: 1.71s
# 730:	learn: 0.0002417	total: 4.62s	remaining: 1.7s
# 731:	learn: 0.0002407	total: 4.63s	remaining: 1.7s
# 732:	learn: 0.0002389	total: 4.64s	remaining: 1.69s
# 733:	learn: 0.0002376	total: 4.64s	remaining: 1.68s
# 734:	learn: 0.0002369	total: 4.65s	remaining: 1.68s
# 735:	learn: 0.0002355	total: 4.66s	remaining: 1.67s
# 736:	learn: 0.0002354	total: 4.66s	remaining: 1.66s
# 737:	learn: 0.0002336	total: 4.67s	remaining: 1.66s
# 738:	learn: 0.0002331	total: 4.67s	remaining: 1.65s
# 739:	learn: 0.0002330	total: 4.68s	remaining: 1.64s
# 740:	learn: 0.0002306	total: 4.69s	remaining: 1.64s
# 741:	learn: 0.0002304	total: 4.69s	remaining: 1.63s
# 742:	learn: 0.0002299	total: 4.7s	remaining: 1.63s
# 743:	learn: 0.0002295	total: 4.71s	remaining: 1.62s
# 744:	learn: 0.0002293	total: 4.71s	remaining: 1.61s
# 745:	learn: 0.0002283	total: 4.72s	remaining: 1.61s
# 746:	learn: 0.0002282	total: 4.72s	remaining: 1.6s
# 747:	learn: 0.0002279	total: 4.73s	remaining: 1.59s
# 748:	learn: 0.0002271	total: 4.74s	remaining: 1.59s
# 749:	learn: 0.0002259	total: 4.74s	remaining: 1.58s
# 750:	learn: 0.0002253	total: 4.75s	remaining: 1.57s
# 751:	learn: 0.0002241	total: 4.75s	remaining: 1.57s
# 752:	learn: 0.0002222	total: 4.76s	remaining: 1.56s
# 753:	learn: 0.0002217	total: 4.77s	remaining: 1.55s
# 754:	learn: 0.0002207	total: 4.77s	remaining: 1.55s
# 755:	learn: 0.0002206	total: 4.78s	remaining: 1.54s
# 756:	learn: 0.0002197	total: 4.78s	remaining: 1.53s
# 757:	learn: 0.0002190	total: 4.79s	remaining: 1.53s
# 758:	learn: 0.0002174	total: 4.8s	remaining: 1.52s
# 759:	learn: 0.0002167	total: 4.8s	remaining: 1.52s
# 760:	learn: 0.0002161	total: 4.81s	remaining: 1.51s
# 761:	learn: 0.0002157	total: 4.82s	remaining: 1.5s
# 762:	learn: 0.0002144	total: 4.82s	remaining: 1.5s
# 763:	learn: 0.0002134	total: 4.83s	remaining: 1.49s
# 764:	learn: 0.0002128	total: 4.83s	remaining: 1.48s
# 765:	learn: 0.0002126	total: 4.84s	remaining: 1.48s
# 766:	learn: 0.0002122	total: 4.85s	remaining: 1.47s
# 767:	learn: 0.0002114	total: 4.85s	remaining: 1.47s
# 768:	learn: 0.0002113	total: 4.86s	remaining: 1.46s
# 769:	learn: 0.0002106	total: 4.87s	remaining: 1.45s
# 770:	learn: 0.0002097	total: 4.87s	remaining: 1.45s
# 771:	learn: 0.0002086	total: 4.88s	remaining: 1.44s
# 772:	learn: 0.0002082	total: 4.88s	remaining: 1.43s
# 773:	learn: 0.0002073	total: 4.89s	remaining: 1.43s
# 774:	learn: 0.0002058	total: 4.9s	remaining: 1.42s
# 775:	learn: 0.0002045	total: 4.91s	remaining: 1.42s
# 776:	learn: 0.0002043	total: 4.91s	remaining: 1.41s
# 777:	learn: 0.0002037	total: 4.92s	remaining: 1.4s
# 778:	learn: 0.0002031	total: 4.92s	remaining: 1.4s
# 779:	learn: 0.0002014	total: 4.93s	remaining: 1.39s
# 780:	learn: 0.0002000	total: 4.94s	remaining: 1.38s
# 781:	learn: 0.0001996	total: 4.94s	remaining: 1.38s
# 782:	learn: 0.0001996	total: 4.95s	remaining: 1.37s
# 783:	learn: 0.0001995	total: 4.96s	remaining: 1.36s
# 784:	learn: 0.0001988	total: 4.96s	remaining: 1.36s
# 785:	learn: 0.0001980	total: 4.97s	remaining: 1.35s
# 786:	learn: 0.0001972	total: 4.97s	remaining: 1.35s
# 787:	learn: 0.0001964	total: 4.98s	remaining: 1.34s
# 788:	learn: 0.0001963	total: 4.99s	remaining: 1.33s
# 789:	learn: 0.0001955	total: 4.99s	remaining: 1.33s
# 790:	learn: 0.0001954	total: 5s	remaining: 1.32s
# 791:	learn: 0.0001950	total: 5s	remaining: 1.31s
# 792:	learn: 0.0001949	total: 5.01s	remaining: 1.31s
# 793:	learn: 0.0001947	total: 5.02s	remaining: 1.3s
# 794:	learn: 0.0001947	total: 5.02s	remaining: 1.29s
# 795:	learn: 0.0001943	total: 5.03s	remaining: 1.29s
# 796:	learn: 0.0001942	total: 5.04s	remaining: 1.28s
# 797:	learn: 0.0001939	total: 5.04s	remaining: 1.28s
# 798:	learn: 0.0001934	total: 5.05s	remaining: 1.27s
# 799:	learn: 0.0001933	total: 5.05s	remaining: 1.26s
# 800:	learn: 0.0001920	total: 5.06s	remaining: 1.26s
# 801:	learn: 0.0001906	total: 5.07s	remaining: 1.25s
# 802:	learn: 0.0001906	total: 5.07s	remaining: 1.24s
# 803:	learn: 0.0001905	total: 5.08s	remaining: 1.24s
# 804:	learn: 0.0001892	total: 5.08s	remaining: 1.23s
# 805:	learn: 0.0001891	total: 5.09s	remaining: 1.23s
# 806:	learn: 0.0001890	total: 5.1s	remaining: 1.22s
# 807:	learn: 0.0001880	total: 5.1s	remaining: 1.21s
# 808:	learn: 0.0001879	total: 5.11s	remaining: 1.21s
# 809:	learn: 0.0001875	total: 5.12s	remaining: 1.2s
# 810:	learn: 0.0001874	total: 5.12s	remaining: 1.19s
# 811:	learn: 0.0001863	total: 5.13s	remaining: 1.19s
# 812:	learn: 0.0001862	total: 5.13s	remaining: 1.18s
# 813:	learn: 0.0001861	total: 5.14s	remaining: 1.17s
# 814:	learn: 0.0001857	total: 5.15s	remaining: 1.17s
# 815:	learn: 0.0001851	total: 5.16s	remaining: 1.16s
# 816:	learn: 0.0001850	total: 5.16s	remaining: 1.16s
# 817:	learn: 0.0001834	total: 5.17s	remaining: 1.15s
# 818:	learn: 0.0001832	total: 5.17s	remaining: 1.14s
# 819:	learn: 0.0001820	total: 5.18s	remaining: 1.14s
# 820:	learn: 0.0001815	total: 5.18s	remaining: 1.13s
# 821:	learn: 0.0001810	total: 5.19s	remaining: 1.12s
# 822:	learn: 0.0001802	total: 5.2s	remaining: 1.12s
# 823:	learn: 0.0001801	total: 5.2s	remaining: 1.11s
# 824:	learn: 0.0001789	total: 5.21s	remaining: 1.1s
# 825:	learn: 0.0001788	total: 5.21s	remaining: 1.1s
# 826:	learn: 0.0001788	total: 5.22s	remaining: 1.09s
# 827:	learn: 0.0001786	total: 5.23s	remaining: 1.08s
# 828:	learn: 0.0001774	total: 5.23s	remaining: 1.08s
# 829:	learn: 0.0001767	total: 5.24s	remaining: 1.07s
# 830:	learn: 0.0001765	total: 5.24s	remaining: 1.07s
# 831:	learn: 0.0001758	total: 5.25s	remaining: 1.06s
# 832:	learn: 0.0001753	total: 5.26s	remaining: 1.05s
# 833:	learn: 0.0001746	total: 5.26s	remaining: 1.05s
# 834:	learn: 0.0001736	total: 5.27s	remaining: 1.04s
# 835:	learn: 0.0001733	total: 5.28s	remaining: 1.03s
# 836:	learn: 0.0001724	total: 5.28s	remaining: 1.03s
# 837:	learn: 0.0001720	total: 5.29s	remaining: 1.02s
# 838:	learn: 0.0001706	total: 5.29s	remaining: 1.01s
# 839:	learn: 0.0001705	total: 5.3s	remaining: 1.01s
# 840:	learn: 0.0001696	total: 5.3s	remaining: 1s
# 841:	learn: 0.0001695	total: 5.31s	remaining: 997ms
# 842:	learn: 0.0001689	total: 5.32s	remaining: 990ms
# 843:	learn: 0.0001683	total: 5.33s	remaining: 984ms
# 844:	learn: 0.0001678	total: 5.33s	remaining: 978ms
# 845:	learn: 0.0001676	total: 5.34s	remaining: 972ms
# 846:	learn: 0.0001663	total: 5.34s	remaining: 965ms
# 847:	learn: 0.0001649	total: 5.35s	remaining: 959ms
# 848:	learn: 0.0001648	total: 5.36s	remaining: 953ms
# 849:	learn: 0.0001640	total: 5.36s	remaining: 946ms
# 850:	learn: 0.0001631	total: 5.37s	remaining: 940ms
# 851:	learn: 0.0001622	total: 5.38s	remaining: 934ms
# 852:	learn: 0.0001613	total: 5.38s	remaining: 928ms
# 853:	learn: 0.0001610	total: 5.39s	remaining: 921ms
# 854:	learn: 0.0001605	total: 5.39s	remaining: 915ms
# 855:	learn: 0.0001604	total: 5.4s	remaining: 909ms
# 856:	learn: 0.0001594	total: 5.41s	remaining: 902ms
# 857:	learn: 0.0001590	total: 5.41s	remaining: 896ms
# 858:	learn: 0.0001586	total: 5.42s	remaining: 890ms
# 859:	learn: 0.0001575	total: 5.42s	remaining: 883ms
# 860:	learn: 0.0001571	total: 5.43s	remaining: 877ms
# 861:	learn: 0.0001567	total: 5.44s	remaining: 871ms
# 862:	learn: 0.0001564	total: 5.45s	remaining: 865ms
# 863:	learn: 0.0001557	total: 5.45s	remaining: 858ms
# 864:	learn: 0.0001556	total: 5.46s	remaining: 852ms
# 865:	learn: 0.0001553	total: 5.46s	remaining: 845ms
# 866:	learn: 0.0001543	total: 5.47s	remaining: 839ms
# 867:	learn: 0.0001539	total: 5.47s	remaining: 833ms
# 868:	learn: 0.0001538	total: 5.48s	remaining: 826ms
# 869:	learn: 0.0001535	total: 5.49s	remaining: 820ms
# 870:	learn: 0.0001528	total: 5.49s	remaining: 814ms
# 871:	learn: 0.0001524	total: 5.5s	remaining: 807ms
# 872:	learn: 0.0001522	total: 5.5s	remaining: 801ms
# 873:	learn: 0.0001513	total: 5.51s	remaining: 795ms
# 874:	learn: 0.0001509	total: 5.52s	remaining: 788ms
# 875:	learn: 0.0001497	total: 5.52s	remaining: 782ms
# 876:	learn: 0.0001496	total: 5.53s	remaining: 776ms
# 877:	learn: 0.0001485	total: 5.54s	remaining: 770ms
# 878:	learn: 0.0001479	total: 5.54s	remaining: 763ms
# 879:	learn: 0.0001469	total: 5.55s	remaining: 757ms
# 880:	learn: 0.0001468	total: 5.56s	remaining: 751ms
# 881:	learn: 0.0001457	total: 5.56s	remaining: 744ms
# 882:	learn: 0.0001457	total: 5.57s	remaining: 738ms
# 883:	learn: 0.0001448	total: 5.58s	remaining: 732ms
# 884:	learn: 0.0001439	total: 5.58s	remaining: 726ms
# 885:	learn: 0.0001434	total: 5.59s	remaining: 719ms
# 886:	learn: 0.0001423	total: 5.59s	remaining: 713ms
# 887:	learn: 0.0001413	total: 5.6s	remaining: 707ms
# 888:	learn: 0.0001410	total: 5.61s	remaining: 700ms
# 889:	learn: 0.0001406	total: 5.61s	remaining: 694ms
# 890:	learn: 0.0001394	total: 5.62s	remaining: 688ms
# 891:	learn: 0.0001391	total: 5.63s	remaining: 681ms
# 892:	learn: 0.0001390	total: 5.63s	remaining: 675ms
# 893:	learn: 0.0001383	total: 5.64s	remaining: 669ms
# 894:	learn: 0.0001383	total: 5.64s	remaining: 662ms
# 895:	learn: 0.0001380	total: 5.65s	remaining: 656ms
# 896:	learn: 0.0001379	total: 5.66s	remaining: 650ms
# 897:	learn: 0.0001369	total: 5.66s	remaining: 643ms
# 898:	learn: 0.0001362	total: 5.67s	remaining: 637ms
# 899:	learn: 0.0001362	total: 5.67s	remaining: 631ms
# 900:	learn: 0.0001361	total: 5.68s	remaining: 624ms
# 901:	learn: 0.0001360	total: 5.68s	remaining: 618ms
# 902:	learn: 0.0001352	total: 5.69s	remaining: 611ms
# 903:	learn: 0.0001347	total: 5.7s	remaining: 605ms
# 904:	learn: 0.0001337	total: 5.7s	remaining: 599ms
# 905:	learn: 0.0001335	total: 5.71s	remaining: 592ms
# 906:	learn: 0.0001333	total: 5.72s	remaining: 586ms
# 907:	learn: 0.0001324	total: 5.72s	remaining: 580ms
# 908:	learn: 0.0001323	total: 5.73s	remaining: 573ms
# 909:	learn: 0.0001317	total: 5.73s	remaining: 567ms
# 910:	learn: 0.0001310	total: 5.74s	remaining: 561ms
# 911:	learn: 0.0001298	total: 5.75s	remaining: 554ms
# 912:	learn: 0.0001296	total: 5.75s	remaining: 548ms
# 913:	learn: 0.0001290	total: 5.76s	remaining: 542ms
# 914:	learn: 0.0001288	total: 5.76s	remaining: 535ms
# 915:	learn: 0.0001280	total: 5.77s	remaining: 529ms
# 916:	learn: 0.0001279	total: 5.78s	remaining: 523ms
# 917:	learn: 0.0001278	total: 5.78s	remaining: 516ms
# 918:	learn: 0.0001277	total: 5.79s	remaining: 510ms
# 919:	learn: 0.0001269	total: 5.79s	remaining: 504ms
# 920:	learn: 0.0001260	total: 5.8s	remaining: 497ms
# 921:	learn: 0.0001259	total: 5.8s	remaining: 491ms
# 922:	learn: 0.0001258	total: 5.81s	remaining: 485ms
# 923:	learn: 0.0001258	total: 5.82s	remaining: 478ms
# 924:	learn: 0.0001257	total: 5.82s	remaining: 472ms
# 925:	learn: 0.0001255	total: 5.83s	remaining: 466ms
# 926:	learn: 0.0001254	total: 5.84s	remaining: 460ms
# 927:	learn: 0.0001253	total: 5.84s	remaining: 453ms
# 928:	learn: 0.0001251	total: 5.85s	remaining: 447ms
# 929:	learn: 0.0001250	total: 5.85s	remaining: 441ms
# 930:	learn: 0.0001242	total: 5.86s	remaining: 434ms
# 931:	learn: 0.0001242	total: 5.87s	remaining: 428ms
# 932:	learn: 0.0001236	total: 5.87s	remaining: 422ms
# 933:	learn: 0.0001236	total: 5.88s	remaining: 415ms
# 934:	learn: 0.0001234	total: 5.88s	remaining: 409ms
# 935:	learn: 0.0001228	total: 5.89s	remaining: 403ms
# 936:	learn: 0.0001221	total: 5.89s	remaining: 396ms
# 937:	learn: 0.0001221	total: 5.9s	remaining: 390ms
# 938:	learn: 0.0001208	total: 5.91s	remaining: 384ms
# 939:	learn: 0.0001205	total: 5.91s	remaining: 378ms
# 940:	learn: 0.0001204	total: 5.92s	remaining: 371ms
# 941:	learn: 0.0001203	total: 5.93s	remaining: 365ms
# 942:	learn: 0.0001198	total: 5.93s	remaining: 359ms
# 943:	learn: 0.0001196	total: 5.94s	remaining: 352ms
# 944:	learn: 0.0001185	total: 5.95s	remaining: 346ms
# 945:	learn: 0.0001183	total: 5.95s	remaining: 340ms
# 946:	learn: 0.0001177	total: 5.96s	remaining: 334ms
# 947:	learn: 0.0001175	total: 5.96s	remaining: 327ms
# 948:	learn: 0.0001168	total: 5.97s	remaining: 321ms
# 949:	learn: 0.0001158	total: 5.98s	remaining: 315ms
# 950:	learn: 0.0001156	total: 5.98s	remaining: 308ms
# 951:	learn: 0.0001147	total: 5.99s	remaining: 302ms
# 952:	learn: 0.0001142	total: 6s	remaining: 296ms
# 953:	learn: 0.0001141	total: 6s	remaining: 289ms
# 954:	learn: 0.0001133	total: 6.01s	remaining: 283ms
# 955:	learn: 0.0001132	total: 6.01s	remaining: 277ms
# 956:	learn: 0.0001126	total: 6.02s	remaining: 270ms
# 957:	learn: 0.0001124	total: 6.03s	remaining: 264ms
# 958:	learn: 0.0001117	total: 6.03s	remaining: 258ms
# 959:	learn: 0.0001112	total: 6.04s	remaining: 252ms
# 960:	learn: 0.0001105	total: 6.04s	remaining: 245ms
# 961:	learn: 0.0001099	total: 6.05s	remaining: 239ms
# 962:	learn: 0.0001098	total: 6.05s	remaining: 233ms
# 963:	learn: 0.0001098	total: 6.06s	remaining: 226ms
# 964:	learn: 0.0001095	total: 6.07s	remaining: 220ms
# 965:	learn: 0.0001095	total: 6.07s	remaining: 214ms
# 966:	learn: 0.0001094	total: 6.08s	remaining: 208ms
# 967:	learn: 0.0001092	total: 6.09s	remaining: 201ms
# 968:	learn: 0.0001091	total: 6.09s	remaining: 195ms
# 969:	learn: 0.0001091	total: 6.1s	remaining: 189ms
# 970:	learn: 0.0001090	total: 6.11s	remaining: 182ms
# 971:	learn: 0.0001090	total: 6.11s	remaining: 176ms
# 972:	learn: 0.0001085	total: 6.12s	remaining: 170ms
# 973:	learn: 0.0001079	total: 6.13s	remaining: 164ms
# 974:	learn: 0.0001078	total: 6.13s	remaining: 157ms
# 975:	learn: 0.0001070	total: 6.14s	remaining: 151ms
# 976:	learn: 0.0001068	total: 6.15s	remaining: 145ms
# 977:	learn: 0.0001061	total: 6.15s	remaining: 138ms
# 978:	learn: 0.0001056	total: 6.16s	remaining: 132ms
# 979:	learn: 0.0001055	total: 6.17s	remaining: 126ms
# 980:	learn: 0.0001054	total: 6.17s	remaining: 120ms
# 981:	learn: 0.0001048	total: 6.18s	remaining: 113ms
# 982:	learn: 0.0001047	total: 6.18s	remaining: 107ms
# 983:	learn: 0.0001043	total: 6.19s	remaining: 101ms
# 984:	learn: 0.0001043	total: 6.2s	remaining: 94.3ms
# 985:	learn: 0.0001041	total: 6.2s	remaining: 88ms
# 986:	learn: 0.0001031	total: 6.21s	remaining: 81.8ms
# 987:	learn: 0.0001028	total: 6.21s	remaining: 75.5ms
# 988:	learn: 0.0001022	total: 6.22s	remaining: 69.2ms
# 989:	learn: 0.0001017	total: 6.23s	remaining: 62.9ms
# 990:	learn: 0.0001014	total: 6.23s	remaining: 56.6ms
# 991:	learn: 0.0001011	total: 6.24s	remaining: 50.3ms
# 992:	learn: 0.0001009	total: 6.25s	remaining: 44ms
# 993:	learn: 0.0001008	total: 6.25s	remaining: 37.7ms
# 994:	learn: 0.0001001	total: 6.26s	remaining: 31.4ms
# 995:	learn: 0.0001000	total: 6.26s	remaining: 25.2ms
# 996:	learn: 0.0000999	total: 6.27s	remaining: 18.9ms
# 997:	learn: 0.0000998	total: 6.28s	remaining: 12.6ms
# 998:	learn: 0.0000996	total: 6.28s	remaining: 6.29ms
# 999:	learn: 0.0000995	total: 6.29s	remaining: 0us

# %%
# # 최적의 하이퍼파라미터로 학습된 릿지 회귀 모델을 저장합니다. 
# best_ridge = ridge_model.best_estimator_

# # 최적의 하이퍼파라미터로 학습된 랜덤포레스트 모델을 저장합니다. 
# best_rf = rf_model.best_estimator_

# # # 최적의 하이퍼파라미터로 학습된 캣부스트 회귀 모델을 저장합니다. 
# # best_cbr = cbr_model.best_estimator_

# %% [markdown]
# <a name='05-04'></a>
# ### 5.4 최종 모델 구축
#
# 릿지 모델과 랜덤 포레스트 모델을 평가하고, 이 둘의 조합인 앙상블 모델을 구축합니다.

# %%
# 학습용 데이터셋의 타깃 변수 예측 
y_pred_tr_ridge = np.expm1(ridge_model.predict(x_train_))
y_pred_tr_rf = np.expm1(rf_model.predict(x_train_))
y_pred_tr_cbr = np.expm1(cbr_model.predict(x_train_))

# 검증용 데이터셋의 타깃 변수 예측 
y_pred_va_ridge = np.expm1(ridge_model.predict(x_valid))
y_pred_va_rf = np.expm1(rf_model.predict(x_valid))
y_pred_va_cbr = np.expm1(cbr_model.predict(x_valid))


# 앙상블 모형의 학습 및 검증 데이터에 대한 타깃 변수 예측 
y_pred_tr_en= np.mean([y_pred_tr_ridge, y_pred_tr_rf, y_pred_tr_cbr], axis=0)
y_pred_va_en= np.mean([y_pred_va_ridge, y_pred_va_rf, y_pred_va_cbr], axis=0)

# 학습 데이터셋의 RMSE 계산 
rmse_tr_ridge = rmse(np.expm1(y_train_), y_pred_tr_ridge)
rmse_tr_rf = rmse(np.expm1(y_train_), y_pred_tr_rf)
rmse_tr_en = rmse(np.expm1(y_train_), y_pred_tr_en)
rmse_tr_cbr = rmse(np.expm1(y_train_), y_pred_tr_cbr)

# 검증 데이터셋의 RMSE 계산 
rmse_va_ridge = rmse(np.expm1(y_valid), y_pred_va_ridge)
rmse_va_rf = rmse(np.expm1(y_valid), y_pred_va_rf)
rmse_va_en = rmse(np.expm1(y_valid), y_pred_va_en)
rmse_va_cbr = rmse(np.expm1(y_valid), y_pred_va_cbr)


print(f'\n**** RIDGE\n')
print(f'Train RMSE: {rmse_tr_ridge}\n')
print(f'Valid RMSE: {rmse_va_ridge}\n')

print(f'\n**** Random Forest\n')
print(f'Train RMSE: {rmse_tr_rf}\n')
print(f'Valid RMSE: {rmse_va_rf}\n')

print(f'\n**** CatBoostRegressor\n')
print(f'Train RMSE: {rmse_tr_cbr}\n')
print(f'Valid RMSE: {rmse_va_cbr}\n')


print(f'\n**** Ensemble\n')
print(f'Train RMSE: {rmse_tr_en}\n')
print(f'Valid RMSE: {rmse_va_en}\n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vm/qw01phdd0gvfvb6qnb3_bk680000gn/T/ipykernel_6676/3010809990.py in <module>
#      21
#      22 # 검증 데이터셋의 RMSE 계산
# ---> 23 rmse_va_ridge = rmse(np.expm1(y_valid), y_pred_va_ridge)
#      24 rmse_va_rf = rmse(np.expm1(y_valid), y_pred_va_rf)
#      25 rmse_va_en = rmse(np.expm1(y_valid), y_pred_va_en)
#
# /var/folders/vm/qw01phdd0gvfvb6qnb3_bk680000gn/T/ipykernel_6676/1713748318.py in rmse(y_true, y_pred)
#       2 def rmse(y_true,y_pred):
#       3
# ----> 4     return round(mean_squared_error(y_true, y_pred,squared=False),4)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# ---> 96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      97
#      98     if y_true.ndim == 1:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
scaler = StandardScaler()
x_train[col_numerical] = scaler.fit_transform(x_train[col_numerical])
x_test[col_numerical] = scaler.transform(x_test[col_numerical])

# %%
y_train = np.log1p(y_train)

# %%
rf_params = {'max_features': [5,6], 'n_estimators': [120, 200]}
rf_model_test = GridSearchCV(RandomForestRegressor(random_state=1), param_grid=rf_params, scoring='neg_root_mean_squared_error', refit=True) 
rf_model_test.fit(x_train,y_train) 

best_rf_test = rf_model_test.best_estimator_

cbr_model_test = CatBoostRegressor(random_state=1, iterations=100)
cbr_model_test.fit(x_train,y_train)
# Out:
# Learning rate set to 0.237657
# 0:	learn: 0.0062935	total: 19.4ms	remaining: 1.92s
# 1:	learn: 0.0061315	total: 25.9ms	remaining: 1.27s
# 2:	learn: 0.0059497	total: 32ms	remaining: 1.03s
# 3:	learn: 0.0057881	total: 38.1ms	remaining: 915ms
# 4:	learn: 0.0056585	total: 43.9ms	remaining: 834ms
# 5:	learn: 0.0055232	total: 49.9ms	remaining: 782ms
# 6:	learn: 0.0054431	total: 55.6ms	remaining: 739ms
# 7:	learn: 0.0052896	total: 61.5ms	remaining: 707ms
# 8:	learn: 0.0052331	total: 67.4ms	remaining: 681ms
# 9:	learn: 0.0051220	total: 73.2ms	remaining: 659ms
# 10:	learn: 0.0050534	total: 79.2ms	remaining: 641ms
# 11:	learn: 0.0049630	total: 85.2ms	remaining: 625ms
# 12:	learn: 0.0048652	total: 90.8ms	remaining: 608ms
# 13:	learn: 0.0047770	total: 96.8ms	remaining: 595ms
# 14:	learn: 0.0047151	total: 102ms	remaining: 580ms
# 15:	learn: 0.0046649	total: 108ms	remaining: 568ms
# 16:	learn: 0.0045991	total: 114ms	remaining: 557ms
# 17:	learn: 0.0044477	total: 120ms	remaining: 547ms
# 18:	learn: 0.0043915	total: 126ms	remaining: 538ms
# 19:	learn: 0.0043318	total: 132ms	remaining: 528ms
# 20:	learn: 0.0042734	total: 138ms	remaining: 518ms
# 21:	learn: 0.0042299	total: 144ms	remaining: 509ms
# 22:	learn: 0.0041766	total: 151ms	remaining: 505ms
# 23:	learn: 0.0041248	total: 157ms	remaining: 496ms
# 24:	learn: 0.0040506	total: 163ms	remaining: 488ms
# 25:	learn: 0.0039788	total: 168ms	remaining: 478ms
# 26:	learn: 0.0039127	total: 174ms	remaining: 471ms
# 27:	learn: 0.0038372	total: 180ms	remaining: 464ms
# 28:	learn: 0.0037926	total: 186ms	remaining: 455ms
# 29:	learn: 0.0037373	total: 191ms	remaining: 447ms
# 30:	learn: 0.0036378	total: 198ms	remaining: 440ms
# 31:	learn: 0.0036085	total: 205ms	remaining: 435ms
# 32:	learn: 0.0035474	total: 211ms	remaining: 429ms
# 33:	learn: 0.0034604	total: 218ms	remaining: 423ms
# 34:	learn: 0.0034142	total: 225ms	remaining: 417ms
# 35:	learn: 0.0034020	total: 232ms	remaining: 412ms
# 36:	learn: 0.0033896	total: 238ms	remaining: 406ms
# 37:	learn: 0.0032895	total: 245ms	remaining: 400ms
# 38:	learn: 0.0032007	total: 252ms	remaining: 394ms
# 39:	learn: 0.0031720	total: 257ms	remaining: 386ms
# 40:	learn: 0.0031085	total: 265ms	remaining: 381ms
# 41:	learn: 0.0030370	total: 272ms	remaining: 376ms
# 42:	learn: 0.0030271	total: 278ms	remaining: 369ms
# 43:	learn: 0.0029612	total: 285ms	remaining: 362ms
# 44:	learn: 0.0028754	total: 291ms	remaining: 355ms
# 45:	learn: 0.0028260	total: 296ms	remaining: 348ms
# 46:	learn: 0.0027670	total: 302ms	remaining: 341ms
# 47:	learn: 0.0027013	total: 308ms	remaining: 334ms
# 48:	learn: 0.0026266	total: 314ms	remaining: 327ms
# 49:	learn: 0.0026182	total: 320ms	remaining: 320ms
# 50:	learn: 0.0026107	total: 326ms	remaining: 314ms
# 51:	learn: 0.0025451	total: 332ms	remaining: 307ms
# 52:	learn: 0.0024509	total: 339ms	remaining: 300ms
# 53:	learn: 0.0024448	total: 345ms	remaining: 294ms
# 54:	learn: 0.0023851	total: 351ms	remaining: 287ms
# 55:	learn: 0.0023376	total: 357ms	remaining: 281ms
# 56:	learn: 0.0022921	total: 363ms	remaining: 274ms
# 57:	learn: 0.0022862	total: 370ms	remaining: 268ms
# 58:	learn: 0.0022386	total: 375ms	remaining: 261ms
# 59:	learn: 0.0021735	total: 381ms	remaining: 254ms
# 60:	learn: 0.0021135	total: 387ms	remaining: 247ms
# 61:	learn: 0.0021079	total: 393ms	remaining: 241ms
# 62:	learn: 0.0021009	total: 400ms	remaining: 235ms
# 63:	learn: 0.0020557	total: 406ms	remaining: 228ms
# 64:	learn: 0.0020512	total: 412ms	remaining: 222ms
# 65:	learn: 0.0020003	total: 418ms	remaining: 215ms
# 66:	learn: 0.0019532	total: 425ms	remaining: 209ms
# 67:	learn: 0.0019105	total: 431ms	remaining: 203ms
# 68:	learn: 0.0019063	total: 436ms	remaining: 196ms
# 69:	learn: 0.0018811	total: 442ms	remaining: 189ms
# 70:	learn: 0.0018306	total: 448ms	remaining: 183ms
# 71:	learn: 0.0017821	total: 454ms	remaining: 176ms
# 72:	learn: 0.0017478	total: 460ms	remaining: 170ms
# 73:	learn: 0.0017249	total: 466ms	remaining: 164ms
# 74:	learn: 0.0016891	total: 472ms	remaining: 157ms
# 75:	learn: 0.0016601	total: 478ms	remaining: 151ms
# 76:	learn: 0.0016318	total: 484ms	remaining: 145ms
# 77:	learn: 0.0015852	total: 490ms	remaining: 138ms
# 78:	learn: 0.0015552	total: 496ms	remaining: 132ms
# 79:	learn: 0.0015433	total: 502ms	remaining: 126ms
# 80:	learn: 0.0015208	total: 508ms	remaining: 119ms
# 81:	learn: 0.0014918	total: 514ms	remaining: 113ms
# 82:	learn: 0.0014511	total: 520ms	remaining: 107ms
# 83:	learn: 0.0014341	total: 527ms	remaining: 100ms
# 84:	learn: 0.0014126	total: 532ms	remaining: 93.9ms
# 85:	learn: 0.0013928	total: 538ms	remaining: 87.6ms
# 86:	learn: 0.0013528	total: 544ms	remaining: 81.3ms
# 87:	learn: 0.0013271	total: 550ms	remaining: 75ms
# 88:	learn: 0.0013059	total: 556ms	remaining: 68.7ms
# 89:	learn: 0.0012830	total: 562ms	remaining: 62.4ms
# 90:	learn: 0.0012545	total: 568ms	remaining: 56.1ms
# 91:	learn: 0.0012442	total: 573ms	remaining: 49.8ms
# 92:	learn: 0.0012213	total: 579ms	remaining: 43.6ms
# 93:	learn: 0.0011898	total: 585ms	remaining: 37.3ms
# 94:	learn: 0.0011535	total: 590ms	remaining: 31.1ms
# 95:	learn: 0.0011205	total: 596ms	remaining: 24.8ms
# 96:	learn: 0.0010873	total: 603ms	remaining: 18.7ms
# 97:	learn: 0.0010847	total: 609ms	remaining: 12.4ms
# 98:	learn: 0.0010626	total: 615ms	remaining: 6.21ms
# 99:	learn: 0.0010390	total: 621ms	remaining: 0us

# %%
y_pred_test_rf = np.expm1(best_rf_test.predict(x_test))
y_pred_test_cbr = np.expm1(cbr_model_test.predict(x_test))
y_pred_test_en= np.mean([y_pred_test_rf, y_pred_test_cbr], axis=0)

rmse_test_en = rmse(np.expm1(y_test), y_pred_test_en)
rmse_test_cbr = rmse(np.expm1(y_test), y_pred_test_cbr)
rmse_test_rf = rmse(np.expm1(y_test), y_pred_test_rf)

print(f'Ensemble: Test RMSE: {rmse_test_en}')
print(f'CBR: Test RMSE: {rmse_test_cbr}')
print(f'RF: Test RMSE: {rmse_test_rf}')
# Out:
# Ensemble: Test RMSE: 7.181
# CBR: Test RMSE: 7.5431
# RF: Test RMSE: 7.0928
